# %%
from os import listdir
from os.path import isfile, join
import json

products = {}

webs = [f for f in listdir('/home/sunji/EM_sigmod/2013_camera_specs')]
for w in webs:
    products[w] = {}
    items = [f for f in listdir('/home/sunji/EM_sigmod/2013_camera_specs/'+w)]
    for it in items:
        with open('/home/sunji/EM_sigmod/2013_camera_specs/'+w+'/'+it, 'r') as f:
            data = json.load(f)
            products[w][it.split('.')[0]] = data

# %%
import pandas as pd
products_labeled = pd.read_csv('/home/sunji/EM_sigmod/sigmod_medium_labelled_dataset.csv')

# %%
products_labeled
# Out:
#                         left_spec_id                    right_spec_id  label
# 0            www.garricks.com.au//31              www.ebay.com//53278      1
# 1                www.ebay.com//58782              www.ebay.com//24817      0
# 2                www.ebay.com//58782              www.ebay.com//43019      0
# 3                www.ebay.com//42055              www.ebay.com//54403      0
# 4                www.ebay.com//44280                    buy.net//6145      0
# 5                www.ebay.com//42074              www.ebay.com//47107      0
# 6                www.ebay.com//42039              www.ebay.com//43213      0
# 7          www.mypriceindia.com//211          www.garricks.com.au//31      0
# 8                www.ebay.com//59297          www.priceme.co.nz//2246      0
# 9                www.ebay.com//58588              www.ebay.com//42196      0
# 10               www.ebay.com//54776              www.ebay.com//45946      0
# 11           www.shopbot.com.au//331          www.priceme.co.nz//1762      0
# 12               www.ebay.com//53871          www.shopbot.com.au//260      0
# 13               www.ebay.com//43741                 www.ilgs.net//47      0
# 14         www.mypriceindia.com//211              www.ebay.com//43019      0
# 15            www.shopmania.in//1646         www.pricedekho.com//1088      0
# 16               www.ebay.com//46468         www.shopbot.com.au//1301      0
# 17               www.ebay.com//41954  www.ukdigitalcameras.co.uk//130      0
# 18               www.ebay.com//46524              www.ebay.com//44635      1
# 19           www.shopbot.com.au//331        www.mypriceindia.com//155      1
# 20               www.ebay.com//58704              www.ebay.com//54400      0
# 21               www.ebay.com//53871              www.ebay.com//57363      0
# 22               www.ebay.com//59061              www.ebay.com//55439      0
# 23           www.garricks.com.au//66              www.ebay.com//58781      0
# 24          www.mypriceindia.com//22              www.ebay.com//25120      0
# 25               www.ebay.com//54324        www.mypriceindia.com//155      0
# 26              www.walmart.com//697          www.garricks.com.au//66      0
# 27               www.ebay.com//43503              www.ebay.com//47191      0
# 28               www.ebay.com//54333     www.wexphotographic.com//601      0
# 29               www.ebay.com//54217              www.ebay.com//60118      0
# ...                              ...                              ...    ...
# 46635            www.ebay.com//43228          www.shopbot.com.au//401      0
# 46636            www.ebay.com//44643              www.ebay.com//44553      0
# 46637            www.ebay.com//55768              www.ebay.com//45946      0
# 46638     www.camerafarm.com.au//829       www.pcconnection.com//4476      0
# 46639         www.shopmania.in//1458     www.wexphotographic.com//601      0
# 46640       www.pricedekho.com//1198              www.ebay.com//60718      0
# 46641              cammarkt.com//413             www.gosale.com//1049      0
# 46642            www.gosale.com//953              www.ebay.com//57000      0
# 46643            www.ebay.com//46830              www.ebay.com//46098      0
# 46644            www.ebay.com//42902              www.ebay.com//42433      0
# 46645            www.ebay.com//55912     www.wexphotographic.com//198      0
# 46646            www.ebay.com//52928              www.ebay.com//24330      0
# 46647            www.ebay.com//24887              www.ebay.com//56369      1
# 46648            www.ebay.com//54114              www.ebay.com//58750      1
# 46649            www.ebay.com//42902         www.mypriceindia.com//57      0
# 46650            www.ebay.com//55745              www.ebay.com//56661      0
# 46651            www.ebay.com//54217         www.shopbot.com.au//1460      0
# 46652            www.ebay.com//58782          www.shopbot.com.au//401      0
# 46653            www.ebay.com//55745              www.ebay.com//55380      0
# 46654            www.ebay.com//53179              www.ebay.com//42504      0
# 46655        www.priceme.co.nz//2043              www.ebay.com//44274      0
# 46656            www.ebay.com//42598          www.shopbot.com.au//388      0
# 46657            www.ebay.com//45946              www.ebay.com//54400      0
# 46658      www.mypriceindia.com//775              www.ebay.com//57139      0
# 46659            www.ebay.com//53179              www.ebay.com//56678      1
# 46660       www.shopbot.com.au//1593     www.wexphotographic.com//589      0
# 46661       www.shopbot.com.au//1325              www.ebay.com//41983      0
# 46662            www.ebay.com//55745              www.ebay.com//57722      0
# 46663            www.ebay.com//42668              www.ebay.com//25180      0
# 46664  www.eglobalcentral.co.uk//135       www.camerafarm.com.au//829      0
#
# [46665 rows x 3 columns]

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.ukdigitalcameras.co.uk'].items():
    camera_ids.append('www.ukdigitalcameras.co.uk//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model' in v:
        model.add(v['model'])
    if 'colour' in v:
        color.add(v['colour'])
    if 'camera resolution' in v:
        resolution.add(v['camera resolution'])
    if 'sensitivity' in v:
        sensitivity.add(v['sensitivity'])
    if 'stablization' in v:
        stablization.add(v['stablization'])
    if 'battery' in v:
        battery.add(v['battery'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.ukdigitalcameras.co.uk.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.wexphotographic.com'].items():
    camera_ids.append('www.wexphotographic.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model' in v:
        model.add(v['model'])
    if 'colour' in v:
        color.add(v['colour'])
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    if 'iso max' in v:
        sensitivity.add(v['iso max'])
    if 'image stabilisation' in v:
        stablization.add(v['image stabilisation'])
    if 'battery model' in v:
        battery.add(v['battery model'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])

Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.wexphotographic.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.canon-europe.com'].items():
    camera_ids.append('www.canon-europe.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model' in v:
        model.add(v['model'])
    if 'colour' in v:
        color.add(v['colour'])
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    if 'iso sensitivity' in v:
        if type(v['iso sensitivity']) == list:
            sensitivity.add(v['iso sensitivity'][0])
        else:
            sensitivity.add(v['iso sensitivity'])
    if 'image stabilisation' in v:
        if type(v['image stabilisation']) == list:
            for ss in v['image stabilisation']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilisation'])
    if 'batteries' in v:
        battery.add(v['batteries'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])

Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.canon-europe.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.price-hunt.com'].items():
    camera_ids.append('www.price-hunt.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model id' in v:
        model.add(v['model id'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'optical sensor resolution in megapixel' in v:
        resolution.add(v['optical sensor resolution in megapixel'])
    if 'iso rating' in v:
        if type(v['iso rating']) == list:
            sensitivity.add(v['iso rating'][0])
        else:
            sensitivity.add(v['iso rating'])
    if 'image stabilizer' in v:
        if type(v['image stabilizer']) == list:
            for ss in v['image stabilizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilizer'])
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery type' in v:
        battery.add(v['battery type'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.price-hunt.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.garricks.com.au'].items():
    camera_ids.append('www.garricks.com.au//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model id' in v:
        model.add(v['model id'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'resolution' in v:
        resolution.add(v['resolution'])
    if 'iso rating' in v:
        if type(v['iso rating']) == list:
            sensitivity.add(v['iso rating'][0])
        else:
            sensitivity.add(v['iso rating'])
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery type' in v:
        battery.add(v['battery type'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])

Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.garricks.com.au.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.cambuy.com.au'].items():
    camera_ids.append('www.cambuy.com.au//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model id' in v:
        model.add(v['model id'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
#     if 'number of effective pixels' in v:
#         resolution.add(v['number of effective pixels'])
#     if 'effective pixels' in v:
#         resolution.add(v['effective pixels'])
    for sense_name in v.keys():
        if 'effective' in sense_name.split(' ') and 'pixels' in sense_name.split(' '):
            resolution.add(v[sense_name])
#     if 'sensitivity' in v:
#         if type(v['sensitivity']) == list:
#             sensitivity.add(v['sensitivity'][0])
#         else:
#             sensitivity.add(v['sensitivity'])
#     if 'iso sensitivity' in v:
#         if type(v['iso sensitivity']) == list:
#             sensitivity.add(v['iso sensitivity'][0])
#         else:
#             sensitivity.add(v['iso sensitivity'])
    for sense_name in v.keys():
        if 'sensitivity' in sense_name.split(' '):
            sensitivity.add(v[sense_name])
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'image stabilisation' in v:
        if type(v['image stabilisation']) == list:
            for ss in v['image stabilisation']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilisation'])
    if 'battery' in v:
        battery.add(v['battery'])
    if 'batteries' in v:
        battery.add(v['batteries'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.cambuy.com.au.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.pcconnection.com'].items():
    camera_ids.append('www.pcconnection.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model id' in v:
        model.add(v['model id'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    if 'light sensitivity' in v:
        if type(v['light sensitivity']) == list:
            sensitivity.add(v['light sensitivity'][0])
        else:
            sensitivity.add(v['light sensitivity'])
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery type' in v:
        battery.add(v['battery type'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.pcconnection.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.priceme.co.nz'].items():
    camera_ids.append('www.priceme.co.nz//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'model id' in v:
        model.add(v['model id'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'max image resolution' in v:
        print (v['max image resolution'])
        try:
            width = v['max image resolution'].split('x')[0]
            height = v['max image resolution'].split('x')[1]
            resolution.add(str(int(width) * int(height)))
        except:
            width = v['max image resolution'].split('×')[0]
            height = v['max image resolution'].split('×')[1]
            resolution.add(str(int(width) * int(height)))
    if 'light sensitivity' in v:
        if type(v['light sensitivity']) == list:
            sensitivity.add(v['light sensitivity'][0])
        else:
            sensitivity.add(v['light sensitivity'])
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'image stabilizer' in v:
        if type(v['image stabilizer']) == list:
            for ss in v['image stabilizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilizer'])
    if 'battery type' in v:
        battery.add(v['battery type'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})
# Out:
# 4592x3448
# 4272x2848
# 5184x3456
# 4032x3024
# 3264x2448
# 4896x3672
# 6000x4000
# 5184x3456
# 4608x3456
# 4000x3000
# 4896x3264
# 4592x3448
# 4000x3000
# 4608x3456
# 5472x3648
# 4608x3456
# 4320x3240
# 4608x3456
# 4928x3264
# 5184x3456
# 4256x2848
# 4928x3264
# 4608x3456
# 4272x2848
# 5184x3456
# 4320x3240
# 6000x4000
# 4896x3672
# 4608x3456
# 5472x3648
# 3648x2736
# 4896x3264
# 6000x4000
# 2640 × 1760
# 4272x2848
# 4320x3240
# 3648x2736
# 5184x3456
# 4592x3448
# 5184x3456
# 4912x3264
# 4000x3000
# 4608x3456
# 4896x3264
# 6000x4000
# 4000x3000
# 6000x4000
# 5184x3456
# 4320x3240
# 5472x3648
# 4608x3456
# 6000x4000
# 4256x2832
# 4608x3456
# 5472x3648
# 4320x3240
# 7360x4912
# 4592x3056
# 4608x3072
# 3872x2592
# 3872x2592
# 4288x2848
# 6000x4000
# 4896x3264
# 4608x3456
# 5456x3632
# 5184x3456
# 5184x3456
# 4608x3456
# 5184x3456
# 4608x3456
# 4608x3456
# 4608x3456
# 4928x3264
# 3648x2736
# 4000x3000
# 5184x3456
# 5472x3648
# 4592x3056
# 4592x3056
# 4608x3456
# 4928x3264
# 4608x3456
# 4288x2848
# 3648x2736
# 4912x3264
# 4592x3056
# 4608x3456
# 5472x3648
# 4320x3240
# 4592x3448
# 3648x2736
# 4000x3000
# 4320x3240
# 4896x3672
# 5184x3456
# 4608x3456
# 4592x3448
# 5184x3456
# 5760x3840
# 3648x2736
# 4608x3456

# %%
Cameras.to_csv('www.priceme.co.nz.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['cammarkt.com'].items():
    camera_ids.append('cammarkt.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        if type(v['brand']) == list:
            for b in v['brand']:
                brand.add(b)
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    if 'family line' in v:
        if type(v['family line']) == list:
            for b in v['family line']:
                model.add(b)
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    if 'light sensitivity' in v:
        if type(v['light sensitivity']) == list:
            sensitivity.add(v['light sensitivity'][0])
        else:
            sensitivity.add(v['light sensitivity'])
    if 'image resolutions' in v:
        print (v['image resolutions'])
        try:
            width = v['image resolutions'].split('x')[0]
            height = v['image resolutions'].split('x')[1]
            resolution.add(str(int(width) * int(height)))
        except:
            try:
                width = v['image resolutions'].split('×')[0]
                height = v['image resolutions'].split('×')[1]
                resolution.add(str(int(width) * int(height)))
            except:
                pass
            
    if 'camera resolution' in v:
        if type(v['camera resolution']) == list:
            resolution.add(v['camera resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['camera resolution'].split('Megapixel')[0]+' Megapixel')
    if 'resolution' in v:
        if type(v['resolution']) == list:
            resolution.add(v['resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['resolution'].split('Megapixel')[0]+' Megapixel')
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'features' in v:
        if 'Image Stabilization' in v['features']:
            stablization.add('Yes')
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery type' in v:
        if type(v['battery type']) == list:
            for b in v['battery type']:
                battery.add(b)
        else:
            battery.add(v['battery type'])
    if 'mpn' in v:
        mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])

Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})
# Out:
# 3888 x 2592
# 4928 x 3264
# 4928 x 3264
# 4928 x 3264
# 640 x 480
# 2816 x 2112
# 3072 x 2048
# 3008 x 2000
# 3008 x 2008
# 2304 x 1536
# 3888 x 2592
# 5184 x 3456
# 640 x 480
# 2304 x 1536
# 3008 x 2000
# 720 x 480
# 3072 x 2048
# 4256 x 2832
# 2304 x 1536
# 3872 x 2592
# 3872 x 2592
# 2592 x 1728
# 6000 x 4000
# 3872 x 2592
# 1728 x 1152
# 640 x 480
# 4272 x 2848
# 640 x 480
# 640 x 480
# 4928 x 3264
# 5184 x 3456
# 5432 x 3492
# 3456 x 2304
# 3072 x 2048
# 3504 x 2336
# 3072 x 2048
# 640 x 480
# 2464 x 1632
# 3504 x 2336
# 4928 x 3264
# 3072 x 2048
# 1920 x 1080
# 3936 x 2624
# 720 x 480
# 4288 x 2848
# 6000 x 4000
# 3216 x 2136
# 2304 x 1536
# 2592 x 1728
# 720 x 480
# 2464 x 1632
# 640 x 480
# 4288 x 2848
# 3872 x 2592
# 5184 x 3456
# 4288 x 2428
# 640 x 480
# 2304 x 1536
# 3072 x 2048
# 2304 x 1728
# 640 x 480
# 3888 x 2592
# 3008 x 2000
# 1728 x 1152
# 3072 x 2048
# 2592 x 1728
# 3008 x 2000
# 2304 x 1536
# 2400 x 1600
# 1920 x 1080
# 3504 x 2336
# 6000 x 4000
# 3008 x 2008
# 3072 x 2048
# 2304 x 1536
# 4928 x 3264
# 1920 x 1080
# 1728 x 1152
# 3072 x 2048
# 1920 x 1280
# 720 x 480
# 3072 x 2048
# 3072 x 2048
# 3072 x 2048
# 4928 x 3264
# 3008 x 2000
# 4608 x 3072
# 4928 x 3264
# 4928 x 3264
# 4288 x 2428
# 5184 x 3456
# 3008 x 2008
# 3008 x 2008
# 6000 x 4000
# 4608 x 3072
# 6000 x 4000
# 4608 x 3072
# 1728 x 1152
# 640 x 480
# 2592 x 1728
# 1968 x 1315
# 1920 x 1080
# 4608 x 3072
# 2560 x 1920
# 2816 x 2112
# 3504 x 2336
# 720 x 480
# 4928 x 3264
# 3872 x 2592
# 3072 x 2048
# 3872 x 2592
# 3008 x 2000
# 2592 x 1728
# Unlike optical zoom, digital zoom magnifies the pixels but not the actual image. The resulting image appears bigger, but is not as sharp as with an optical zoom.
# 1728 x 1152
# 720 x 480
# 4928 x 3264
# 6000 x 4000
# 3504 x 2336
# 6000 x 4000
# ['6000 x 4000', '6000 x 4000']
# 3872 x 2592
# 3072 x 2048
# 640 x 480
# 640 x 480
# 3872 x 2592
# 3008 x 2008

# %%
Cameras.to_csv('cammarkt.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.gosale.com'].items():
    camera_ids.append('www.gosale.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    titles = v['product name'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        if type(v['brand']) == list:
            for b in v['brand']:
                brand.add(b)
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    if 'family line' in v:
        if type(v['family line']) == list:
            for b in v['family line']:
                model.add(b)
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    if 'megapixel range' in v:
        resolution.add(v['megapixel range'])
    if 'light sensitivity' in v:
        if type(v['light sensitivity']) == list:
            sensitivity.add(v['light sensitivity'][0])
        else:
            sensitivity.add(v['light sensitivity'])
    if 'image resolutions' in v:
        print (v['image resolutions'])
        try:
            width = v['image resolutions'].split('x')[0]
            height = v['image resolutions'].split('x')[1]
            resolution.add(str(int(width) * int(height)))
        except:
            try:
                width = v['image resolutions'].split('×')[0]
                height = v['image resolutions'].split('×')[1]
                resolution.add(str(int(width) * int(height)))
            except:
                pass
            
    if 'camera resolution' in v:
        if type(v['camera resolution']) == list:
            resolution.add(v['camera resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['camera resolution'].split('Megapixel')[0]+' Megapixel')
    if 'resolution' in v:
        if type(v['resolution']) == list:
            resolution.add(v['resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['resolution'].split('Megapixel')[0]+' Megapixel')
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'features' in v:
        if 'Image Stabilization' in v['features']:
            stablization.add('Yes')
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery type' in v:
        if type(v['battery type']) == list:
            for b in v['battery type']:
                battery.add(b)
        else:
            battery.add(v['battery type'])
    if 'product number mpn' in v:
        mpn.add(v['product number mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])

Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.gosale.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.mypriceindia.com'].items():
    camera_ids.append('www.mypriceindia.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t.lower() in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb.lower() in models:
                model.add(bbb)
#     titles = v['product name'].split(' ')
#     for t in titles:
#         if t in brands:
#             brand.add(t)
#     for step in range(3):
#         for start in range(len(titles) - step):
#             bbb = ' '.join(titles[start:start+step])
#             if bbb in models:
#                 model.add(bbb)
    if 'brand' in v:
        if type(v['brand']) == list:
            for b in v['brand']:
                brand.add(b)
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    if 'family line' in v:
        if type(v['family line']) == list:
            for b in v['family line']:
                model.add(b)
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'camera resolution' in v:
        resolution.add(v['camera resolution'])
    if 'max resolution' in v:
        resolution.add(v['max resolution'])
    if 'iso rating' in v:
        if type(v['iso rating']) == list:
            sensitivity.add(v['iso rating'][0])
        else:
            sensitivity.add(v['iso rating'])
    if 'image resolutions' in v:
        print (v['image resolutions'])
        try:
            width = v['image resolutions'].split('x')[0]
            height = v['image resolutions'].split('x')[1]
            resolution.add(str(int(width) * int(height)))
        except:
            try:
                width = v['image resolutions'].split('×')[0]
                height = v['image resolutions'].split('×')[1]
                resolution.add(str(int(width) * int(height)))
            except:
                pass
            
    if 'camera resolution' in v:
        if type(v['camera resolution']) == list:
            resolution.add(v['camera resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['camera resolution'].split('Megapixel')[0]+' Megapixel')
    if 'resolution' in v:
        if type(v['resolution']) == list:
            resolution.add(v['resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['resolution'].split('Megapixel')[0]+' Megapixel')
    if 'megapixels' in v:
        resolution.add(v['megapixels'])
    
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'features' in v:
        if 'Image Stabilization' in v['features']:
            stablization.add('Yes')
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery type' in v:
        if type(v['battery type']) == list:
            for b in v['battery type']:
                battery.add(b)
        else:
            battery.add(v['battery type'])
    if 'product number mpn' in v:
        mpn.add(v['product number mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.mypriceindia.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.camerafarm.com.au'].items():
    camera_ids.append('www.camerafarm.com.au//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
#     titles = v['product name'].split(' ')
#     for t in titles:
#         if t in brands:
#             brand.add(t)
#     for step in range(3):
#         for start in range(len(titles) - step):
#             bbb = ' '.join(titles[start:start+step])
#             if bbb in models:
#                 model.add(bbb)
    if 'brand' in v:
        if type(v['brand']) == list:
            for b in v['brand']:
                brand.add(b)
        else:
            brand.add(v['brand'].split(' ')[0])
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    if 'manuf no' in v:
        if type(v['manuf no']) == list:
            for b in v['manuf no']:
                model.add(b)
        else:
            model.add(v['manuf no'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        color.add(v['color'])
    if 'camera resolution' in v:
        resolution.add(v['camera resolution'])
    if 'max resolution' in v:
        resolution.add(v['max resolution'])
    if 'iso sensitivity' in v:
        if type(v['iso sensitivity']) == list:
            sensitivity.add(v['iso sensitivity'][0])
        else:
            sensitivity.add(v['iso sensitivity'])
    if 'highest standard iso sensitivity' in v:
        if type(v['highest standard iso sensitivity']) == list:
            sensitivity.add(v['highest standard iso sensitivity'][0])
        else:
            sensitivity.add(v['highest standard iso sensitivity'])
    if 'image resolutions' in v:
        print (v['image resolutions'])
        try:
            width = v['image resolutions'].split('x')[0]
            height = v['image resolutions'].split('x')[1]
            resolution.add(str(int(width) * int(height)))
        except:
            try:
                width = v['image resolutions'].split('×')[0]
                height = v['image resolutions'].split('×')[1]
                resolution.add(str(int(width) * int(height)))
            except:
                pass
            
    if 'camera resolution' in v:
        if type(v['camera resolution']) == list:
            resolution.add(v['camera resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['camera resolution'].split('Megapixel')[0]+' Megapixel')
    if 'resolution' in v:
        if type(v['resolution']) == list:
            resolution.add(v['resolution'][0].split('Megapixel')[0]+' Megapixel')
        else:
            resolution.add(v['resolution'].split('Megapixel')[0]+' Megapixel')
    if 'total pixels' in v:
        resolution.add(v['total pixels'])
    if 'effective pixelss' in v:
        resolution.add(v['effective pixels'])
    
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'features' in v:
        if 'Image Stabilization' in v['features']:
            stablization.add('Yes')
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery grip' in v:
        if type(v['battery grip']) == list:
            for b in v['battery grip']:
                battery.add(b)
        else:
            battery.add(v['battery grip'])
    if 'battery  batteries' in v:
        if type(v['battery  batteries']) == list:
            for b in v['battery  batteries']:
                battery.add(b)
        else:
            battery.add(v['battery  batteries'])
    if 'product number mpn' in v:
        mpn.add(v['product number mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
Cameras.to_csv('www.camerafarm.com.au.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.ebay.com'].items():
    camera_ids.append('www.ebay.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
#     titles = v['product name'].split(' ')
#     for t in titles:
#         if t in brands:
#             brand.add(t)
#     for step in range(3):
#         for start in range(len(titles) - step):
#             bbb = ' '.join(titles[start:start+step])
#             if bbb in models:
#                 model.add(bbb)
    if 'brand' in v:
        if type(v['brand']) == list:
            for b in v['brand']:
                brand.add(b)
        else:
            brand.add(v['brand'].split(' ')[0])
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    if 'model' in v:
        if type(v['model']) == list:
            for b in v['model']:
                model.add(b)
        else:
            model.add(v['model'])
    if 'series' in v:
        model.add(v['series'])
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    if 'sensor resolution' in v:
        if type(v['sensor resolution']) == list:
            for b in v['sensor resolution']:
                resolution.add(b)
        else:
            resolution.add(v['sensor resolution'])
    if 'max resolution' in v:
        resolution.add(v['max resolution'])
    if 'iso sensitivity' in v:
        if type(v['iso sensitivity']) == list:
            for b in v['iso sensitivity']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso sensitivity'])
    if 'light sensitivity max' in v:
        if type(v['light sensitivity max']) == list:
            for b in v['light sensitivity max']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['light sensitivity max'])
    if 'image resolutions' in v:
        print (v['image resolutions'])
        try:
            width = v['image resolutions'].split('x')[0]
            height = v['image resolutions'].split('x')[1]
            resolution.add(str(int(width) * int(height)))
        except:
            try:
                width = v['image resolutions'].split('×')[0]
                height = v['image resolutions'].split('×')[1]
                resolution.add(str(int(width) * int(height)))
            except:
                pass
            
    if 'megapixels' in v:
        if type(v['megapixels']) == list:
            for b in v['megapixels']:
                sensitivity.add(b)
        else:
            resolution.add(v['megapixels'])
    
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for ss in v['image stabilization']:
                stablization.add(ss)
        else:
            stablization.add(v['image stabilization'])
    if 'features' in v:
        if 'Image Stabilization' in v['features']:
            stablization.add('Yes')
    if 'image stablizer' in v:
        if type(v['image stablizer']) == list:
            for ss in v['image stablizer']:
                stablization.add(ss)
        else:
            stablization.add(v['image stablizer'])
    if 'battery grip' in v:
        if type(v['battery grip']) == list:
            for b in v['battery grip']:
                battery.add(b)
        else:
            battery.add(v['battery grip'])
    if 'battery  batteries' in v:
        if type(v['battery  batteries']) == list:
            for b in v['battery  batteries']:
                battery.add(b)
        else:
            battery.add(v['battery  batteries'])
    if 'mpn' in v:
        if type(v['mpn']) == list:
            for b in v['mpn']:
                mpn.add(b)
        else:
            mpn.add(v['mpn'])
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})
# Out:
# 1600 x 1200, 2272 x 1704, 2816 x 2112, 3648 x 2048, 3648 x 2736, 640 x 480
# 1936 x 1296, 2896 x 1944, 3872 x 2592
# 1936 x 1296, 2896 x 1944, 3872 x 2592
# 1024 x 768, 1600 x 1200, 2272 x 1704, 640 x 480
# 1600 x 1200, 2592 x 1944, 3264 x 2448, 4000 x 2248, 4000 x 3000, 640 x 480

# %%
Cameras.to_csv('www.ebay.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.shopbot.com.au'].items():
    camera_ids.append('www.shopbot.com.au//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'digital camera warehouse nsw vic qld' in v:
        desc = v['digital camera warehouse nsw vic qld']
    elif 'nsw vic qld' in v:
        desc = v['nsw vic qld']
    else:
        desc = ''
    if type(desc) == list:
        desc = ' '.join(desc)
    xx = desc.lower().split('megapixel')[0].split(' ')
    for i in reversed(range(len(xx))):
        if len(xx[i]) > 0:
            if xx[i] != 'offer':
                resolution.add(xx[i]+' megapixel')
            break
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.buzzillions.com'].items():
    camera_ids.append('www.buzzillions.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t.lower() in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb.lower() in models:
                model.add(bbb)
                
    if 'camera color' in v:
        if type(v['camera color']) == list:
            for b in v['camera color']:
                color.add(b)
        else:
            color.add(v['camera color'])
    
    if 'compatible battery' in v:
        if type(v['compatible battery']) == list:
            for b in v['compatible battery']:
                battery.add(b)
        else:
            battery.add(v['compatible battery'])
        
    if 'megapixels' in v:
        if type(v['megapixels']) == list:
            for b in v['megapixels']:
                battery.add(b + ' megapixel')
        else:
            resolution.add(v['megapixels']+' megapixel')
        
    if 'sensitivity' in v:
        if type(v['sensitivity']) == list:
            for b in v['sensitivity']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['sensitivity'])

    if 'anti shake mode' in v:
        stablization.add(v['anti shake mode'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

Cameras.to_csv('www.buzzillions.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.flipkart.com'].items():
    camera_ids.append('www.flipkart.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model id' in v:
        model.add(v['model id'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'compatible battery' in v:
        if type(v['compatible battery']) == list:
            for b in v['compatible battery']:
                battery.add(b)
        else:
            battery.add(v['compatible battery'])
        
    if 'still image size 43' in v:
        if type(v['still image size 43']) == list:
            for b in v['still image size 43']:
                battery.add(b)
        else:
            resolution.add(v['still image size 43'])
        
    if 'iso rating' in v:
        if type(v['iso rating']) == list:
            for b in v['iso rating']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso rating'])

    if 'mode optical' in v:
        stablization.add(v['mode optical'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.eglobalcentral.co.uk'].items():
    camera_ids.append('www.eglobalcentral.co.uk//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model' in v:
        model.add(v['model'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'battery' in v:
        if type(v['battery']) == list:
            for b in v['battery']:
                battery.add(b)
        else:
            battery.add(v['battery'])
        
    if 'max resolution' in v:
        if type(v['max resolution']) == list:
            for b in v['max resolution']:
                resolution.add(b)
        else:
            resolution.add(v['max resolution'])
        
    if 'iso sensitivity' in v:
        if type(v['iso sensitivity']) == list:
            for b in v['iso sensitivity']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso sensitivity'])

    
    if 'image stabilisation' in v:
        stablization.add(v['image stabilisation'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.pricedekho.com'].items():
    camera_ids.append('www.pricedekho.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model' in v:
        model.add(v['model'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'supplied battery' in v:
        if type(v['supplied battery']) == list:
            for b in v['supplied battery']:
                battery.add(b)
        else:
            battery.add(v['supplied battery'])
        
    if 'pixels' in v:
        if type(v['pixels']) == list:
            for b in v['pixels']:
                resolution.add(b)
        else:
            resolution.add(v['pixels'])
            
    if 'resolution' in v:
        if type(v['resolution']) == list:
            for b in v['resolution']:
                resolution.add(b)
        else:
            resolution.add(v['resolution'])
        
    if 'iso rating' in v:
        if type(v['iso rating']) == list:
            for b in v['iso rating']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso rating'])

    
    if 'image stabilizer' in v:
        stablization.add(v['image stabilizer'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.shopmania.in'].items():
    camera_ids.append('www.shopmania.in//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model' in v:
        model.add(v['model'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'battery' in v:
        if type(v['battery']) == list:
            for b in v['battery']:
                battery.add(b)
        else:
            battery.add(v['battery'])
        
    if 'pixels' in v:
        if type(v['pixels']) == list:
            for b in v['pixels']:
                resolution.add(b)
        else:
            resolution.add(v['pixels'])
            
    if 'resolution' in v:
        if type(v['resolution']) == list:
            for b in v['resolution']:
                resolution.add(b)
        else:
            resolution.add(v['resolution'])
        
    if 'light sensitivity iso' in v:
        if type(v['light sensitivity iso']) == list:
            for b in v['light sensitivity iso']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['light sensitivity iso'])

    
    if 'image stabilizer' in v:
        stablization.add(v['image stabilizer'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.walmart.com'].items():
    camera_ids.append('www.walmart.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model no' in v:
        model.add(v['model no'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'battery' in v:
        if type(v['battery']) == list:
            for b in v['battery']:
                battery.add(b)
        else:
            battery.add(v['battery'])
        
    if 'pixels' in v:
        if type(v['pixels']) == list:
            for b in v['pixels']:
                resolution.add(b)
        else:
            resolution.add(v['pixels'])
            
    if 'resolution megapixels' in v:
        if type(v['resolution megapixels']) == list:
            for b in v['resolution megapixels']:
                resolution.add(b)
        else:
            resolution.add(v['resolution megapixels'])
        
    if 'light sensitivity iso' in v:
        if type(v['light sensitivity iso']) == list:
            for b in v['light sensitivity iso']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['light sensitivity iso'])

    
    if 'image stabilizer' in v:
        stablization.add(v['image stabilizer'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['buy.net'].items():
    camera_ids.append('buy.net//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model no' in v:
        model.add(v['model no'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'battery' in v:
        if type(v['battery']) == list:
            for b in v['battery']:
                battery.add(b)
        else:
            battery.add(v['battery'])
        
    if 'effective megapixels' in v:
        if type(v['effective megapixels']) == list:
            for b in v['effective megapixels']:
                resolution.add(b)
        else:
            resolution.add(v['effective megapixels'])
            
    if 'resolution megapixels' in v:
        if type(v['resolution megapixels']) == list:
            for b in v['resolution megapixels']:
                resolution.add(b)
        else:
            resolution.add(v['resolution megapixels'])
        
    if 'iso equivalencies' in v:
        if type(v['iso equivalencies']) == list:
            for b in v['iso equivalencies']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso equivalencies'])

    
    if 'image stabilization' in v:
        stablization.add(v['image stabilization'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.alibaba.com'].items():
    camera_ids.append('www.alibaba.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t.lower() in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb.lower() in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    
    if 'model no' in v:
        model.add(v['model no'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'color' in v:
        if type(v['color']) == list:
            for b in v['color']:
                color.add(b)
        else:
            color.add(v['color'])
    
    if 'battery' in v:
        if type(v['battery']) == list:
            for b in v['battery']:
                battery.add(b)
        else:
            battery.add(v['battery'])
        
    if 'effective pixels' in v:
        if type(v['effective pixels']) == list:
            for b in v['effective pixels']:
                resolution.add(b)
        else:
            resolution.add(v['effective pixels'])
            
    if 'max image resolution ' in v:
        if type(v['max image resolution ']) == list:
            for b in v['max image resolution ']:
                resolution.add(b)
        else:
            resolution.add(v['max image resolution '])
        
    if 'iso equivalencies' in v:
        if type(v['iso equivalencies']) == list:
            for b in v['iso equivalencies']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso equivalencies'])

    
    if 'image stabilization' in v:
        stablization.add(v['image stabilization'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})

Cameras.to_csv('www.alibaba.com.csv', index=False)

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.ilgs.net'].items():
    camera_ids.append('www.ilgs.net//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t.lower() in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb.lower() in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    
    if 'model no' in v:
        model.add(v['model no'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'colour of product' in v:
        if type(v['colour of product']) == list:
            for b in v['colour of product']:
                color.add(b)
        else:
            color.add(v['colour of product'])
    
    if 'battery type' in v:
        if type(v['battery type']) == list:
            for b in v['battery type']:
                battery.add(b)
        else:
            battery.add(v['battery type'])
        
    if 'megapixel' in v:
        if type(v['megapixel']) == list:
            for b in v['megapixel']:
                resolution.add(b)
        else:
            resolution.add(v['megapixel'])
            
    if 'max image resolution ' in v:
        if type(v['max image resolution ']) == list:
            for b in v['max image resolution ']:
                resolution.add(b)
        else:
            resolution.add(v['max image resolution '])
        
    if 'iso sensitivity' in v:
        if type(v['iso sensitivity']) == list:
            for b in v['iso sensitivity']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso sensitivity'])

    
    if 'image stabilizer' in v:
        stablization.add(v['image stabilizer'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
Cameras = pd.DataFrame({'camera_ids':camera_ids,'camera_brand':camera_brand,'camera_model':camera_model,
                        'camera_model':camera_model,'camera_color':camera_color,'camera_resolution':camera_resolution,
                       'camera_sensitivity':camera_sensitivity,'camera_stablization':camera_stablization,'camera_battery':camera_battery,
                       'camera_mpn':camera_mpn, 'camera_title':camera_title})
Cameras.to_csv('www.ilgs.net.csv', index=False)

# %%
print (products.keys())
# Out:
# dict_keys(['www.ukdigitalcameras.co.uk', 'www.wexphotographic.com', 'www.canon-europe.com', 'www.price-hunt.com', 'www.garricks.com.au', 'www.cambuy.com.au', 'www.pcconnection.com', 'www.priceme.co.nz', 'cammarkt.com', 'www.gosale.com', 'www.mypriceindia.com', 'www.camerafarm.com.au', 'www.ebay.com', 'www.shopbot.com.au', 'www.buzzillions.com', 'www.flipkart.com', 'www.eglobalcentral.co.uk', 'www.pricedekho.com', 'www.shopmania.in', 'www.walmart.com', 'buy.net', 'www.alibaba.com', 'www.ilgs.net', 'www.henrys.com'])

# %%
products['www.henrys.com']
# Out:
# {'184': {'<page title>': 'NIKON COOLPIX P340 BLACK 12MP 5X 3" 32019',
#   'ac power adapter': 'EH-71P (Included); EH-62F (Sold Separately)',
#   'additional zoom': 'None',
#   'approx resolution': '12MP',
#   'aspect ratio': 'NA',
#   'battery': 'EN-EL12',
#   'builtin flash': 'Yes',
#   'builtin memory': '56MB',
#   'burst rate': '10 fps',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'Micro USB; HDMI micro Connector (D), Wi-Fi',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '103.0 x 58.3 x 32.0mm (4.1 x 2.3 x 1.3 in.)',
#   'display screen type': 'LCD',
#   'dustproof': 'No',
#   'effective pixels': '12.2MP',
#   'exposure modes': 'Programmed auto exposure, Aperture-priority auto, Exposure bracketing, Manual, Shutter priority auto',
#   'external flash connection': 'No',
#   'file formats': 'JPEG, RAW, MOV',
#   'flash modes': 'TTL Auto',
#   'focus range': 'W: 30cm to infinity, T: 50cm to infinity, Macro mode: 2cm to infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-25600',
#   'lens': '5.1-25.5mm (35mm equivalent: 24-120mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Matrix, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)',
#   'optical zoom': '5x',
#   'remote control': 'via Wi-Fi',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/1.7" CMOS',
#   'shockproof': 'No',
#   'shutter': '60 sec - 1/4000 sec',
#   'viewfinder type': 'LCD',
#   'waterproofing': 'No',
#   'weight': '194g (6.9 oz.)',
#   'white balance modes': 'Auto, Color Temperature, Cloudy, Daylight, Flash, Fluorescent, Incandescent, White Balance Preset'},
#  '196': {'1 star': '(0)',
#   '2 star': '(0)',
#   '3 star': '(0)',
#   '4 star': '(1)',
#   '5 star': '(0)',
#   '<page title>': 'PANASONIC DMCTS5A BLUE 16.1MP 4.6X WATERPROOF DMCTS5A',
#   'ac power adapter': '110-240V AC',
#   'additional zoom': '9.3x',
#   'approx resolution': '16MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'Rechargeable Lithium Ion Battery Pack',
#   'builtin flash': 'Yes',
#   'builtin memory': '15MB',
#   'burst rate': 'Up to 10 fps at 16.1 MP for up to 10 frames\nUp to 40 fps at 5 MP\nUp to 60 fps at 3 MP',
#   'camera type': 'Waterproof',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Blue',
#   'connectivity': 'AV Output, HDMI D, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'Yes',
#   'effective pixels': '16.1MP',
#   'exposure modes': 'Modes: Manual, Programmed Auto\nCompensation: -2 EV to +2 EV (in 1/3 EV steps)',
#   'external flash connection': 'None',
#   'file formats': 'JPEG, MPO',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nForced On\nOff\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Wide: 11.81" (30 cm) - Infinity\nTelephoto: 11.81" (30 cm) - Infinity\nWide Macro: 1.97" (5 cm) - Infinity\nTele Macro: 11.81" (30 cm) - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': 'Leica DC Vario-Elmar, 10 elements in 8 groups\n5 Aspheric, 1 ED\nEFL: 4.9-22.8 mm (35 mm equivalent: 28-128 mm)\nAperture: f/3.3 (W) - 5.9 (T)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Multi',
#   'operatingstorage temperature': '-10 to 40C (14 to 104F)\nHumidity: 0-100%',
#   'optical zoom': '4.6x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.33" CMOS',
#   'shockproof': '6.6 ft.',
#   'shutter': '4-1/1300 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'waterproofing': '13.0m',
#   'white balance modes': 'Auto, Cloudy, Custom, Daylight, Incandescent, Manual, Shade, Tungsten'},
#  '45': {'<page title>': 'SONY DSC-H300B BLACK 20.1MP 35X 3" DSCH300B',
#   'ac power adapter': 'No',
#   'additional zoom': 'NA',
#   'approx resolution': '20MP',
#   'aspect ratio': '4:3, 16:9',
#   'battery': 'AA Battery',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': '0.80 fps',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '2x',
#   'dimensions wxhxd': '129.6 x 5.0 x 122.3mm (5 1/8 x 3 3/4 x 4 7/8 in.)',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'No',
#   'effective pixels': '20.1MP',
#   'exposure modes': 'iAuto, Program Auto, Manual',
#   'external flash connection': 'No',
#   'file formats': 'JPEG, MP4',
#   'flash modes': 'Auto, Flash On, Slow Synchro, Flash Off, Advanced Flash',
#   'focus range': 'W: 1cm (0.03 ft.) to Infinity, T: 350cm (11.48 ft.) to Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-3200',
#   'lens': 'Sony',
#   'memory card type': 'Memory Stick Pro Duo, Memory Stick PRO HG-Duo, SD/SDHC/SDXC',
#   'metering method': 'Multi Pattern, Center Weighted, Spot',
#   'operatingstorage temperature': 'NA',
#   'optical zoom': '35x',
#   'remote control': 'NA',
#   'screen size': '3.0"',
#   'self timer': 'Off, 2 Sec, 10 Sec, portrait1, portrait2',
#   'sensor typesize': '1/2.3" Super HAD CCD',
#   'shockproof': 'No',
#   'shutter': '30 - 1/1500 sec.',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '590g (1 lb., 4.8 oz.)',
#   'white balance modes': 'Auto, Daylight, Cloudy, Fluorescent, Incandescent, Flash, One Push, One Push Set'},
#  '42': {'<page title>': 'FUJI FINEPIX XP200 YELLOW 16MP 5X 3" WATERPROOF 600012725',
#   'ac power adapter': 'N/A',
#   'additional zoom': '2x',
#   'approx resolution': '16MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'NP-50',
#   'builtin flash': 'Yes',
#   'builtin memory': '39MB',
#   'burst rate': 'Up to 10 fps for up to 9 frames\nUp to 5 fps for up to 9 frames\nUp to 3 fps for up to 9 frames\nUp to 60 fps at 2.1 MP for up to 60 frames',
#   'camera type': 'Waterproof',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Yellow',
#   'connectivity': 'HDMI C, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'N/A',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'Yes',
#   'effective pixels': '16.4MP',
#   'exposure modes': 'Modes: Programmed Auto\nCompensation: -2 EV to +2 EV (in .3 EV steps)',
#   'external flash connection': 'None',
#   'file formats': 'JPEG, MPO',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nFlash On w/ Red-eye Reduction\nForced On\nOff\nSlow Sync\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Wide: 1.97\' (60 cm) - Infinity\nTelephoto: 3.28\' (1 m) - Infinity\nWide Macro: 3.54" (9 cm) - 2.62\' (80 cm)\nTele Macro: 1.31\' (40 cm) - 2.62\' (80 cm)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': '13 elements in 11 groups\nEFL: 5-25 mm (35 mm equivalent: 28-140 mm)\nAperture: f/3.9 (W) - 4.9 (T) to f/8',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'TTL 256-zones',
#   'operatingstorage temperature': '-10 to 40C (14 to 104F)\nHumidity: 10-80%',
#   'optical zoom': '5x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" CMOS',
#   'shockproof': '6.6 ft.',
#   'shutter': '4-1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '2 year warranty',
#   'waterproofing': '15.0m',
#   'white balance modes': 'Auto, Fine, Fluorescent, Fluorescent (Day White), Fluorescent (White), Incandescent, Shade'},
#  '148': {'<page title>': 'PANASONIC DMCSZ8K BLACK 14.1MP 16X 3" DMCSZ8K',
#   'ac power adapter': 'AC Adaptor (Input: 110 - 240 V AC) (Included, connect with USB cable)',
#   'additional zoom': '16.9x - 27.0x',
#   'approx resolution': '16MP',
#   'aspect ratio': '4:3, 3:2, 16:9, 1:1',
#   'battery': 'Li-ion Battery Pack (3.6 V, 690 mAh, 2.5 Wh) (Included)',
#   'builtin flash': 'Yes',
#   'builtin memory': '80MB',
#   'burst rate': '1.2 to 3 fps',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output (NTSC), USB (AV/USB Multi)',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '99.8 x 60.4 x 26.5 mm (3.93 x 2.38 x 1.04 inch)',
#   'display screen type': 'TFT Screen LCD Display',
#   'dustproof': 'No',
#   'effective pixels': '16MP',
#   'exposure modes': 'Auto (Program AE)',
#   'external flash connection': 'None',
#   'file formats': 'JPEG, QuickTime Motion JPEG',
#   'flash modes': 'Auto, Auto/Red-eye Reduction, Forced On, Slow Sync./Red-eye Reduction, Forced Off',
#   'focus range': 'Normal / Intelligent Auto / Motion Picture: Wide 3 cm - infinity / Tele 150 cm - infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': '8 elements in 8 groups (4 Aspherical Lenses / 8 Aspherical surfaces / 1 ED Lenses)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Intelligent Multiple',
#   'operatingstorage temperature': 'NA',
#   'optical zoom': '12x',
#   'remote control': 'NA',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.33" CCD',
#   'shockproof': 'No',
#   'shutter': '60 - 1/2,000 sec',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '144g (0.32 lbs.)',
#   'white balance modes': 'Auto / Daylight / Cloudy / Shade / Incandescent / White Set'},
#  '141': {'<page title>': 'CANON POWERSHOT S200 10.1MP CCD 5X 3" WIFI 8408B005',
#   'ac power adapter': 'CB-2LY',
#   'additional zoom': 'None',
#   'approx resolution': '10MP',
#   'aspect ratio': '16:9, 3:2, 4:3, 1:1',
#   'battery': 'NB-6LH',
#   'builtin flash': 'Yes',
#   'builtin memory': 'N/A',
#   'burst rate': '4.5 fps',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'Hi-Speed USB',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'N/A',
#   'dustproof': 'N/A',
#   'effective pixels': '10.1MP',
#   'exposure modes': 'Compensation: +-2 Stops in 1/3-stop increments',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, Flash On, Flash Off',
#   'focus range': '3 cm (1.2 in.) - infinity (W), 30cm (12 in.) - infinity (T)',
#   'image stabilization': 'N/A',
#   'iso sensitivity': '80-6400',
#   'lens': '5.2-26.0mm',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'N/A',
#   'operatingstorage temperature': 'N/A; Humidity: 10-90%',
#   'optical zoom': '5x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec., 10 Sec., Custom',
#   'sensor typesize': '1/1.7" CCD',
#   'shockproof': 'N/A',
#   'shutter': '15-1/2000 sec.',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'waterproofing': 'N/A',
#   'white balance modes': 'Auto, Day Light, Cloudy, Tungsten, Fluorescent, Fluorescent H, Custom'},
#  '146': {'<page title>': 'SIGMA DP3 MERRILL W/50MM F2.8 46MP DP3M',
#   'ac power adapter': 'SAC-5 (Optional)',
#   'additional zoom': 'None',
#   'approx resolution': '46MP',
#   'aspect ratio': '3:2',
#   'battery': 'BP-41',
#   'builtin flash': 'No',
#   'builtin memory': 'N/A',
#   'burst rate': 'Up to 4 fps at 46 MP for up to 7 frames',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, Audio Out, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'None',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '46MP',
#   'exposure modes': 'Modes: Aperture Priority, Manual, Program, Program Shift, Shutter Priority\nCompensation: -3 EV to +3 EV (in .33 EV steps)',
#   'external flash connection': 'Hot Shoe',
#   'file formats': 'JPEG, RAW',
#   'flash modes': 'None',
#   'focus range': 'Macro: 8.90" (22.6 cm) - Infinity',
#   'image stabilization': 'None',
#   'iso sensitivity': '100-6400',
#   'lens': '10 elements in 8 groups\nEFL: 50 mm (35 mm equivalent: 75 mm)\nAperture: f/2.8',
#   'memory card type': 'SD/SDHC/SDXC/MMC',
#   'metering method': 'Center-weighted, Evaluative, Spot',
#   'operatingstorage temperature': 'N/A',
#   'optical zoom': 'None',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '23.5x15.7mm CMOS',
#   'shutter': 'Type: Electronic & Mechanical\nSpeed: 30 - 1/2000 second',
#   'viewfinder type': 'LCD Display',
#   'warranty': '10 year warranty',
#   'white balance modes': 'Auto, Custom, Daylight, Flash, Fluorescent, Incandescent, Overcast, Shade'},
#  '104': {'<page title>': 'FUJIFILM XF1 BROWN 12MP EXR 4X WIDE ANGLE 3" 600012396',
#   'ac power adapter': 'AC-5VX (Optional)',
#   'additional zoom': 'None',
#   'aperture': 'F1.8-F11 (Wide) F4.9-F11 (Telephoto) 1/3EV step (controlled 6-blade aperture diaphragm)',
#   'approx resolution': '12MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'NP-50A',
#   'builtin flash': 'Yes',
#   'builtin memory': '25MB',
#   'burst rate': 'Up to 7 fps at 12 MP\nUp to 10 fps at 8 MP',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Brown',
#   'connectivity': 'HDMI C, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'Intelligent digital zoom approx. 2x (up to 8 x when combined with optical zoom)',
#   'dimensions': '107.9(W) x 61.5(H) x 33.0(D) mm / 4.2(W) x 2.4(H) x 1.2(D)',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '12.0 million pixels',
#   'exposure compensation': '-2.0EV - +2.0EV 1/3EV step',
#   'exposure control': 'TTL 256-zones metering, Multi / Spot / Average',
#   'exposure modes': 'Modes: Aperture Priority, Manual, Programmed Auto, Shutter Priority\nCompensation: -2 EV to +2 EV (in 1/3 EV steps)',
#   'external flash connection': 'None',
#   'file formats': 'JPEG, RAW',
#   'flash': 'Auto flash (super intelligent flash) Effective range: (ISO AUTO (800)), Wide: Approx. 50 cm - 7.4 m / 1.6 ft. - 24.2 ft. Telephoto: Approx. 80 cm - 2.7 m / 2.6 ft. - 8.8 ft. Flash modes: Red-eye removal OFF: Auto, Forced Flash, Suppressed Flash, Slow Synchro., Red-eye removal ON: Red-eye Reduction Auto, Red-eye Reduction & Forced Flash, Suppressed Flash, Red-eye Reduction & Slow Synchro.',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nFlash On\nFlash On w/ Red-eye Reduction\nForced On\nOff\nSlow Sync\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Wide: 1.64\' (50 cm) - Infinity\nTelephoto: 2.62\' (80 cm) - Infinity\nWide Macro: 1.18" (3 cm) - 9.84\' (3 m)\nTele Macro: 1.64\' (50 cm) - 9.84\' (3 m)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-12800',
#   'lcd monitor': '3.0-inch, approx. 460,000 dots, colour LCD monitor, approx. 100% coverage',
#   'lens': 'Fujinon 4x optical zoom lens focal length: f=6.4 - 25.6 mm, equivalent to 25 - 100 mm on a 35 mm format Full-aperture F1.8 (Wide) - F4.9 (Telephoto) Construction: 6 groups 7 lenses (4 aspherical glass molded lenses included)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi, Spot, TTL 256-zones',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)\nHumidity: 10-80%',
#   'optical zoom': '4x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '2/3" CMOS',
#   'shooting modes': 'SP: Natural Light, Natural Light & Flash, Portrait, Portrait Enhancer, Landscape, Sport, Night, Night (Tripod), Fireworks, Sunset, Snow, Beach, Party, Flower, Text, Underwater MODE DIAL: EXR, AUTO, P, S, A, M, C1, C2, Movie, SP, Adv.',
#   'shutter': '30-1/2000 sec',
#   'shutter speed': 'Auto mode: 1/4 sec. to 1/2000* sec. All other modes: 30 sec. to 1/2000* sec.* 1/2000 sec. at small aperture, 1/1000 sec. at full aperture',
#   'viewfinder type': 'LCD Display',
#   'warranty': '2 year warranty',
#   'weight': 'Approx. 225 g / 7.9 oz. (including battery and memory card), Approx. 204 g / 7.1 oz. (excluding battery and memory card)',
#   'white balance modes': 'Auto, Custom, Fluorescent (Day White), Fluorescent (Natural White), Fluorescent (White), Incandescent, Kelvin, Shade, Underwater'},
#  '59': {'<page title>': 'PANASONIC DMCSZ5K BLACK 14MP 10X WIDE ANGLE 3"WIFI DMCSZ5K',
#   'ac power adapter': '110-240V AC',
#   'additional zoom': '20x',
#   'approx resolution': '14MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'Rechargeable Lithium Ion Battery Pack',
#   'builtin flash': 'Yes',
#   'builtin memory': '55MB',
#   'burst rate': 'Up to 1.5 fps at 14.1 MP',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'N/A',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '14.1MP',
#   'exposure modes': 'Modes: Programmed Auto\nCompensation: -2 EV to +2 EV (in 1/3 EV steps)',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nForced On\nOff\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Wide: 19.69" (50 cm) - Infinity\nTelephoto: 59.06" (150 cm) - Infinity\nWide: 1.97" (5 cm) - Infinity\nTelephoto: 59.06" (150 cm) - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': 'Leica DC Vario-Elmar, 9 elements in 7 groups\n4 Aspheric\nEFL: 4.5-45 mm (35 mm equivalent: 25-250 mm)\nAperture: f/3.1 (W) - 5.9 (T) to f/16.0',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Multi',
#   'operatingstorage temperature': 'N/A',
#   'optical zoom': '10x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.33" CCD',
#   'shutter': '8-1/1600 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'white balance modes': 'Auto, Cloudy, Daylight, Incandescent, Shade'},
#  '194': {'<page title>': 'SAMSUNG WB2200F 16MP 60X WIDE ANGLE 3" SMART CAMERA EC-WB2200BPBCA',
#   'ac power adapter': 'NA',
#   'additional zoom': 'NA',
#   'approx resolution': '16MP',
#   'aspect ratio': 'NA',
#   'battery': 'BP-1410',
#   'builtin flash': 'Yes',
#   'builtin memory': '17MB',
#   'burst rate': 'NA',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV, HDMI 1.4 (D), Wi-Fi',
#   'digital point and shoot camera': '.',
#   'digital zoom': '2x',
#   'dimensions wxhxd': '119.4 x 121.9 x 104.1 mm (4.7 x 4.8 x 4.1 in.)',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'No',
#   'effective pixels': '16.4MP',
#   'exposure modes': 'Program AE',
#   'external flash connection': 'No',
#   'file formats': 'Still: NA; Video: MP4',
#   'flash modes': 'Auto, Auto & Red-eye reduction, Fill-in flash, Slow sync, Flash Off, Red-eye fix',
#   'focus range': 'Normal: 80cm-Infinity (Wide), 350cm-infinity(Tele), Macro: 10cm-80cm (Wide), 150cm-350cm (Tele), Auto Macro: 1cm-infinity (Wide), 150cm-infinity (Tele), Super Macro: 1cm (Wide, Minimum Focus Distance)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': '3.58-214.8mm (35mm film equivalent: 20-1200 mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Metering: Multi, Spot, Center-weighted, Face Detection AE, Metering Rang : EV 2-17 (Wide, ISO Auto), EV 4-17 (Tele, ISO Auto)',
#   'operatingstorage temperature': '0 to 40C (32 to 104F),\nHumidity: 5-85%',
#   'optical zoom': '60x',
#   'remote control': 'via Smartphone',
#   'screen size': '3.0"',
#   'self timer': '2 sec., 10 sec.',
#   'sensor typesize': 'BSI CMOS',
#   'shockproof': 'No',
#   'shutter': '8 - 1/2000 sec.',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '635.0 g (1.4 lb.)',
#   'white balance modes': 'Auto WB, Daylight, Cloudy, Fluorescent_H, Fluorescent_L, Tungsten, Custom, K'},
#  '168': {'1 star': '(0)',
#   '2 star': '(0)',
#   '3 star': '(0)',
#   '4 star': '(0)',
#   '5 star': '(4)',
#   '<page title>': 'PANASONIC DMC-FZ200 BLACK 12MP 24X F2.8 3" DMCFZ200K',
#   'ac power adapter': '110-240V AC',
#   'additional zoom': '48x',
#   'approx resolution': '12MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'Rechargeable Lithium Ion Battery Pack',
#   'builtin flash': 'Yes',
#   'builtin memory': '70MB',
#   'burst rate': 'Up to 12 fps at 12.1 MP for up to 12 frames\nUp to 5.5 fps at 12.1 MP for up to 12 frames\nUp to 2 fps at 12.1 MP for up to 12 frames\nUp to 60 fps at 2.5 MP\nUp to 40 fps at 5 MP',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': '2.5mm Sub-mini, HDMI C, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'N/A',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '12.1MP',
#   'exposure modes': 'Modes: Aperture Priority, Manual, Programmed Auto, Shutter Priority\nCompensation: -3 EV to +3 EV (in 1/3 EV steps)',
#   'external flash connection': 'Hot Shoe',
#   'file formats': 'JPEG, MPO, RAW',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nForced On\nOff\nSecond-curtain Sync\nSlow Sync\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Wide: 11.81" (30 cm) - Infinity\nTelephoto: 78.74" (200 cm) - Infinity\nWide: 0.39" (1 cm) - Infinity\nTelephoto: 39.37" (100 cm) - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': 'Leica DC Vario-Elmarit, 14 elements in 11 groups\n5 Aspheric, 3 ED\nEFL: 4.5-108 mm (35 mm equivalent: 25-600 mm)\nAperture: f/2.8 (W) - 2.8 (T) to f/8.0',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi, Spot',
#   'operatingstorage temperature': 'N/A',
#   'optical zoom': '24x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" MOS',
#   'shutter': '60-1/4000 sec',
#   'viewfinder type': 'Electronic, LCD Display',
#   'warranty': '1 year warranty',
#   'white balance modes': 'Auto, Cloudy, Daylight, Flash, Fluorescent (Natural White), Fluorescent (White), Incandescent, Shade'},
#  '210': {'<page title>': 'CANON POWERSHOT SX600HS WHITE 16MP 18X 3" 9341B001',
#   'ac power adapter': 'ACK-40',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': '16:9, 3:2, 4:3, 1:1',
#   'battery': 'NB-6L/NB-6LH',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': '3.9 shots/sec.; 10.5 shots/sec.',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'White',
#   'connectivity': 'HDMI connector (D-type)',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '103.8 x 61.0 x 26.0mm (4.09 x 2.40 x 1.02 in.)',
#   'display screen type': 'TFT Colour',
#   'dustproof': 'No',
#   'effective pixels': '16.0MP',
#   'exposure modes': 'Manual Exposure, Program Shift, Safety Shift, AE Lock',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, Flash On, Slow Synchro, Flash Off',
#   'focus range': 'Normal/Auto: 2.0 in. (5cm) - infinity (W), 3.3 ft. (1m) - infinity (T); Macro: 2.0 in. - 1.6 ft. (5-50cm) (W), 4.6 ft. (1.4m) - infinity (T)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-3200',
#   'lens': '4.5 (W) - 81.0 (T) mm (35mm film equivalent: 25-450mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Evaluative, Center-weighted average, Spot',
#   'operatingstorage temperature': '0-40C (32-104F)',
#   'optical zoom': '18x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec., 10 Sec., Custom',
#   'sensor typesize': '1/2.3" CMOS',
#   'shockproof': 'No',
#   'shutter': '15-1/2000 sec.',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '164g (5.78 oz.)',
#   'white balance modes': 'Auto, Daylight, Cloudy, Tungsten, Fluorescent, Fluorescent H, Custom'},
#  '69': {'1 star': '(1)',
#   '2 star': '(0)',
#   '3 star': '(0)',
#   '4 star': '(0)',
#   '5 star': '(0)',
#   '<page title>': 'PANASONIC DMCZS40S SILVER 18MP 30X WIDE ANGLE 3" DMCZS40S',
#   'ac power adapter': 'NA',
#   'additional zoom': 'NA',
#   'approx resolution': '18MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'NA',
#   'builtin flash': 'Yes',
#   'builtin memory': '12MB',
#   'burst rate': 'Up to 60 fps, varies with Image Size and Features chosen',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Silver',
#   'connectivity': 'NA',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '110.6 x 64.3 x 34.4 mm / (4.35 x 2.53 x 1.35 inch)',
#   'display screen type': 'TFT LCD',
#   'dustproof': 'No',
#   'effective pixels': '18.1MP',
#   'exposure modes': 'Program AE, Aperture Priority AE, Shutter Priority AE, Manual',
#   'external flash connection': 'No',
#   'file formats': 'JPEG, RAW, AVCHD, MP4',
#   'flash modes': 'Auto, Auto/Red-eye Reduction, Forced On, Slow Sync./Red-eye Reduction, Forced Off',
#   'focus range': 'Normal: Wide 50cm - infinity, Tele 200cm - infinity; Motion Picture: Wide 3 cm - infinity, Tele 200 cm - infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': '4.3 to 129mm (35mm equivalent: 24-720mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Intelligent Multiple, Centre-Weighted, Spot',
#   'operatingstorage temperature': 'NA',
#   'optical zoom': '30x',
#   'remote control': 'Yes',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" MOS',
#   'shockproof': 'No',
#   'shutter': '30 sec. - 1/2000 sec.',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '214 g (0.472 lb)',
#   'white balance modes': 'Auto, Daylight, Cloudy, Shade, Incandescent, White Set, White Balance Adjustment (Except Auto)'},
#  '116': {'<page title>': 'NIKON COOLPIX S3600 BLACK 20MP 8X 2.7" 32184',
#   'ac power adapter': 'EH-70P (Included); EH-62G (Sold Separately)',
#   'additional zoom': 'None',
#   'approx resolution': '20MP',
#   'aspect ratio': 'NA',
#   'battery': 'EN-EL19',
#   'builtin flash': 'Yes',
#   'builtin memory': '25MB',
#   'burst rate': '1.1 fps',
#   'camera type': 'Small & Easy',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, USB',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '97.1 x 57.9 x 19.9mm (3.9 x 2.3 x 0.8 in.)\n(19.9 mm)',
#   'display screen type': 'LCD Screen',
#   'dustproof': 'No',
#   'effective pixels': '20.1MP',
#   'exposure modes': 'Programmed auto',
#   'external flash connection': 'No',
#   'file formats': 'JPEG; AVI',
#   'flash modes': 'TTL Auto',
#   'focus range': 'W: 50cm to infinity; T: 1.5m to infinity; Macro: 2cm to infinity',
#   'image stabilization': 'No',
#   'iso sensitivity': '80-3200',
#   'lens': '4.5-36.0mm (35mm equivalent: 25�200 mm lens)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Centre-weighted, Matrix, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)',
#   'optical zoom': '8x',
#   'remote control': 'No',
#   'screen size': '2.7"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" CCD',
#   'shockproof': 'No',
#   'shutter': '4 sec - 1/1500 sec',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '125g (\n4.5 oz.)',
#   'white balance modes': 'Auto, Cloudy, Daylight, Flash, Fluorescent, Incandescent, White Balance Preset'},
#  '233': {'<page title>': 'LEICA X VARIO 16MP APS-C DIGITAL CAMERA 18430',
#   'ac power adapter': 'N/A',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': '(3:2)',
#   'battery': 'BP-DC8',
#   'builtin flash': 'Yes',
#   'builtin memory': '110MB',
#   'burst rate': 'Not stated by Manufacturer',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'Mini USB 2.0 socket, HDMI socket, special socket exclusively for external Leica EVF 2 electronic viewfinder',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'None',
#   'display screen type': 'LCD Widescreen',
#   'dustproof': 'N/A',
#   'effective pixels': '16.2MP',
#   'exposure modes': 'Automatic program, aperture priority, shutter speed priority and manual setting.',
#   'external flash connection': 'None',
#   'file formats': 'DNG, JPEG, MP4',
#   'flash modes': 'Auto, auto/Red-Eye, forced on, forced on/Red eye, Slow Sync, Slow Sync/Red eye, Studio.',
#   'focus range': 'Auto: 11.81" (30 cm) - Infinity',
#   'image stabilization': 'N/A',
#   'iso sensitivity': '100-12500',
#   'lens': '9 elements in 8 groups\n2 Aspheric\nEFL: 18-46 mm (35 mm equivalent: 28-70 mm) Aperture: f/3.5 to 16 (at 28 mm), 6.4 to 16 (at 70 mm) in 1/3 EV increments.',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi-field, Spot',
#   'operatingstorage temperature': 'Not stated by Manufacturer',
#   'optical zoom': '2.5x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 12 Sec',
#   'sensor typesize': 'CMOS sensor, size APS-C (23.6 x 15.7 mm)',
#   'shockproof': 'Not stated by Manufacturer',
#   'shutter': '30-1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '2 year warranty',
#   'waterproofing': 'Not stated by Manufacturer',
#   'white balance modes': 'Auto, Daylight, Cloud, Halogen lighting, Shade, Electronic flash, Manual colour temperature setting, Fine adjustment option for all settings'},
#  '74': {'<page title>': 'LEICA D-LUX 6 GLOSSY BLACK/SILVER 18115',
#   'ac power adapter': 'N/A',
#   'additional zoom': 'None',
#   'approx resolution': '10MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'Rechargeable Lithium Ion Battery Pack',
#   'builtin flash': 'Yes',
#   'builtin memory': '70MB',
#   'burst rate': 'Up to 11 fps at 10 MP for up to 12 frames\nUp to 5 fps at 10 MP for up to 100 frames\nUp to 40 fps at 5 MP for up to 40 frames\nUp to 60 fps at 2.5 MP for up to 60 frames',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, HDMI C, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '10.1MP',
#   'exposure modes': 'Modes: Aperture Priority, Auto, Manual, Programmed Auto, Shutter Priority\nCompensation: -3 EV to +3 EV (in 1/3 EV steps)',
#   'external flash connection': 'Hot Shoe',
#   'file formats': 'JPEG, MPO, RAW',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nForced On\nOff\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Normal: 19.69" (50 cm) - Infinity\nWide Macro: 0.39" (1 cm) - Infinity\nTele Macro: 11.81" (30 cm) - Infinity',
#   'image stabilization': 'N/A',
#   'iso sensitivity': '80-12800',
#   'lens': '11 elements in 10 groups\n5 Aspheric\nEFL: 4.7-17.7 mm (35 mm equivalent: 24-90 mm)\nAperture: f/1.4 (W) - 2.3 (T)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)\nHumidity: 10-80%',
#   'optical zoom': '3.8x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/1.7" CMOS',
#   'shutter': '250-1/4000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '2 year warranty',
#   'white balance modes': 'Auto, Cloudy, Custom, Daylight, Flash, Incandescent, Manual, Shade'},
#  '198': {'<page title>': 'CANON POWERSHOT N 12.1MP CMOS WHITE 8X 2.8 8231B005',
#   'ac power adapter': 'ACK-DC70',
#   'additional zoom': 'None',
#   'approx resolution': '12MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'NB-9L',
#   'builtin flash': 'Yes',
#   'builtin memory': 'N/A',
#   'burst rate': 'Up to 2.3 fps',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'White',
#   'connectivity': 'USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'LCD Rear Touch Screen Tilt LCD',
#   'effective pixels': '12.1MP',
#   'exposure modes': 'Modes: Auto\nCompensation: -2 EV to +2 EV (in 1/3 EV steps)',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto\nFlash On\nOff\nSlow Sync',
#   'focus range': 'Wide: 0.4" (1.02 cm) - Infinity\nTelephoto: 3.3\' (1.01 m) - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-6400',
#   'lens': 'EFL: 5-40 mm (35 mm equivalent: 28-224 mm)\nAperture: f/3.0 (W) - 5.9 (T)',
#   'memory card type': 'Micro SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Evaluative, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)\nHumidity: 10-90%',
#   'optical zoom': '8x',
#   'remote control': 'N/A',
#   'screen size': '2.8"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" CMOS',
#   'shutter': '15-1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'white balance modes': 'Auto, Cloudy, Daylight, Fluorescent, Fluorescent H, Tungsten'},
#  '154': {'1 star': '(0)',
#   '2 star': '(0)',
#   '3 star': '(0)',
#   '4 star': '(0)',
#   '5 star': '(1)',
#   '<page title>': 'NIKON COOLPIX P600 BLACK 16MP 60X 3" 32016',
#   'ac power adapter': 'EH-71P (Included); EH-67A (Sold Separately)',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': 'NA',
#   'battery': 'EN-EL23',
#   'builtin flash': 'Yes',
#   'builtin memory': '56MB',
#   'burst rate': '7 fps',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'Micro USB; HDMI micro Connector (D), Wi-Fi',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '125.0 x 85.0 x 106.5mm (5.0 x 3.4 x 4.2 in.)',
#   'display screen type': 'LCD',
#   'dustproof': 'No',
#   'effective pixels': '16.1MP',
#   'exposure modes': 'Programmed auto exposure, Aperture-priority auto, Exposure bracketing, Manual, Shutter priority auto',
#   'external flash connection': 'No',
#   'file formats': 'JPEG, MOV',
#   'flash modes': 'TTL Auto',
#   'focus range': 'W: 50cm to infinity, T: 2m to infinity, Macro mode: 1cm',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-12800',
#   'lens': '4.3-258mm (35mm equivalent: 24-1440mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Centre-weighted, Matrix, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)',
#   'optical zoom': '60x',
#   'remote control': 'via Wi-Fi',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" CMOS',
#   'shockproof': 'No',
#   'shutter': '15 sec - 1/4000 sec',
#   'viewfinder type': 'LCD',
#   'waterproofing': 'No',
#   'weight': '565g (19.9 oz.)',
#   'white balance modes': 'Auto, Color Temperature, Cloudy, Daylight, Flash, Fluorescent, Incandescent, White Balance Preset'},
#  '214': {'<page title>': 'CANON POWERSHOT SX520HS 16MP 42X 3" CMOS CAMERA 9544B001',
#   'ac power adapter': 'CA-DC10 included with AC Adapter Kit ACK-DC40 (Sold Separately)',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': '16:9, 3:2, 4:3, 1:1',
#   'battery': 'NB-6LH',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': '1.6 shots/sec.; 10 shots/sec.',
#   'camera type': 'Super Zoom',
#   'colour': 'Black',
#   'connectivity': 'Mini-HDMI connector',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '120.0 x 81.7 x 91.9mm (4.72 x 3.22 x 3.62in.)',
#   'display screen type': 'TFT Colour',
#   'dustproof': 'No',
#   'effective pixels': '16.0MP',
#   'exposure modes': 'Manual Exposure, Program Shift, Safety Shift, AE Lock',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, Flash On, Slow Synchro, Flash Off',
#   'focus range': 'Normal: 5cm (2.0 in.) - infinity (W), 1.3m (4.3 ft.) - infinity (T); Auto/Manual: 0cm (0.0 in.) - infinity (W), 1.3m (4.3 ft. ) - infinity (T); Macro AF: 0-50cm (0-1.6 ft. ) (W)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-3200',
#   'lens': '4.3 (W) - 180.6 (T) mm (35mm film equivalent: 24-1008mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Evaluative, Center-weighted average, Spot',
#   'operatingstorage temperature': '0-40C (32-104F)',
#   'optical zoom': '42x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec., 10 Sec., Custom',
#   'sensor typesize': '1/2.3" CMOS',
#   'shockproof': 'No',
#   'shutter': '15-1/2000 sec.',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '417g (14.7 oz.) (camera body only)',
#   'white balance modes': 'Auto, Daylight, Cloudy, Tungsten, Fluorescent, Fluorescent H, Custom'},
#  '113': {'<page title>': 'SONY DSC-W830 SILVER 20.1MP 8X 2.7" DSCW830',
#   'ac power adapter': 'NA',
#   'additional zoom': 'NA',
#   'approx resolution': '20MP',
#   'aspect ratio': '4:3, 16:9',
#   'battery': 'NP-BN',
#   'builtin flash': 'Yes',
#   'builtin memory': 'None',
#   'burst rate': 'Up to 1 fps at 16.1 MP for up to 100 frames',
#   'camera type': 'Small & Easy',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Silver',
#   'connectivity': 'AV Output, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '32x',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'NA',
#   'effective pixels': '20.1MP',
#   'exposure modes': 'iAuto, Program Auto',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto / Flash On / Slow Synchro / Flash Off / Advanced Flash',
#   'focus range': 'Wide: 5 cm - Infinity; Telephoto: 150 cm - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-3200',
#   'lens': 'Carl Zeiss Vario-Tessar, 8 elements in 7 groups\n5 Aspheric\n35 mm equivalent: 25-200 mm\nAperture: f/3.3 - 6.3',
#   'memory card type': 'Memory Stick Duo, Memory Stick Pro Duo, Memory Stick PRO HG-Duo, SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi, Spot',
#   'operatingstorage temperature': 'NA',
#   'optical zoom': '8x',
#   'remote control': 'NA',
#   'screen size': '2.7 "',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" HAD CCD',
#   'shockproof': 'NA',
#   'shutter': '2" - 1/1,600',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'NA',
#   'white balance modes': 'Auto, Cloudy, Daylight, Flash, Fluorescent, Incandescent, One Push'},
#  '152': {'<page title>': 'CANON POWERSHOT ELPH 140IS RED 16MP 8X 2.7" 9147B001',
#   'ac power adapter': 'ACK-90',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': '4:3',
#   'battery': 'NB-11L/NB-11LH',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': '0.8 shots/sec.; 3.3 shots/sec.',
#   'camera type': 'Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Red',
#   'connectivity': 'AV Output, Audio Out',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '95.2 x 54.3 x 22.1mm (3.75 x 2.14 x 0.87 in.)',
#   'display screen type': 'TFT Colour LCD',
#   'dustproof': 'No',
#   'effective pixels': '16.0MP',
#   'exposure modes': 'Manual Exposure, Program Shift, Safety Shift, AE Lock',
#   'external flash connection': 'No',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, Flash On, Slow Synchro, Flash Off',
#   'focus range': 'Auto: 0.4 in. (1 cm) - infinity (W, 4.3 ft. (1.3 m) - infinity (T); Normal: 2.0 in. (5 cm) - infinity (W), 4.3 ft. (1.3 m) - infinity (T); Macro: 0.4 in. - 1.6 ft. (1-50 cm) (W)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-1600',
#   'lens': '5.0 (W) - 40.0 (T) mm (35mm film equivalent: 28 - 224mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Evaluative, Center-weighted average, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)',
#   'optical zoom': '8x',
#   'remote control': 'No',
#   'screen size': '2.7"',
#   'self timer': '2 Sec, 10 Sec, Custom',
#   'sensor typesize': '1/2.3" CCD',
#   'shockproof': 'No',
#   'shutter': '15 sec - 1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '115g (4.06 oz.)',
#   'white balance modes': 'Auto, Daylight, Cloudy, Tungsten, Fluorescent, Fluorescent H, Custom'},
#  '162': {'<page title>': 'SAMSUNG WB250F BLACK 14.2MP 18X 3" CMOS EC-WB250FBPBCA',
#   'ac power adapter': 'N/A',
#   'additional zoom': 'None',
#   'approx resolution': '14MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'SLB-10A',
#   'builtin flash': 'Yes',
#   'builtin memory': '25MB',
#   'burst rate': 'N/A',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'N/A',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '14.2MP',
#   'exposure modes': 'Modes: Aperture Priority, Manual, Programmed Auto, Shutter Priority\nCompensation: -2 EV to +2 EV (in 1/3 EV steps)',
#   'external flash connection': 'N/A',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nFill-in\nOff\nRed-eye Reduction\nSlow Sync',
#   'focus range': 'Wide: 31.50" (80 cm) - Infinity\nTelephoto: 137.80" (350 cm) - Infinity\nWide Macro: 1.97" (5.0 cm) - 31.50" (80 cm)\nTele Macro: 70.87" (180 cm) - 137.80" (350 cm)\nMacro: 1.97" (5.0 cm) - Infinity\nMacro: 70.87" (180 cm) - Infinity\nManual: 1.97" (5.0 cm) - Infinity\nManual: 70.87" (180 cm) - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-3200',
#   'lens': 'EFL: 4.0-72 mm (35 mm equivalent: 24-432 mm)\nAperture: f/3.2 (W) - 5.8 (T)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Face Detection, Multi, Spot',
#   'operatingstorage temperature': 'N/A',
#   'optical zoom': '18x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': 'N/A',
#   'sensor typesize': '1/2.33" CMOS',
#   'shutter': '16-1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'white balance modes': 'Auto, Cloudy, Custom, Daylight, Fluorescent, Fluorescent H, Kelvin, Tungsten'},
#  '83': {'<page title>': 'HASSELBLAD STELLAR SLV,CARBON FIBER GRIP 3012600',
#   'ac power adapter': '3.6 V AC Adaptor AC-UD10/UD11, 5V',
#   'additional zoom': 'N/A',
#   'approx resolution': '20MP',
#   'aspect ratio': '16:9; 4:3',
#   'battery': 'NP-BX1',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': 'N/A',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Silver w/ Carbon Fiber Grip',
#   'connectivity': 'HDMI micro jack, Micro USB (USB2.0)',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'N/A',
#   'display screen type': 'TFT LCD',
#   'dustproof': 'N/A',
#   'effective pixels': '20.2MP',
#   'exposure modes': 'Automatic exposure, Aperture priority, Shutter priority, Manual exposure, Scene Selection (13 modes)',
#   'external flash connection': 'No',
#   'file formats': 'Still: RAW, JPEG; Video: AVCHD, MPEG-4 AVC/H.264',
#   'flash modes': 'N/A',
#   'focus range': 'N/A',
#   'image stabilization': 'Yes',
#   'iso sensitivity': 'N/A',
#   'lens': 'Carl Zeiss Vario-Sonnar T*',
#   'memory card type': 'Memory Stick Duo media, Memory Stick Micro media, SD cards, microSD memory cards',
#   'metering method': 'N/A',
#   'operatingstorage temperature': 'Operating: 0 C to 40 C (32 F to 104 F); Storage: -20 C to 60 C (-4 F to 140 F)',
#   'optical zoom': '3.6x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': 'N/A',
#   'sensor typesize': '13.2 x 8.8 mm CMOS Sensor',
#   'shockproof': 'N/A',
#   'shutter': 'N/A',
#   'viewfinder type': 'N/A',
#   'warranty': 'Canadian Warranty: Two Years Parts & Labour',
#   'waterproofing': 'N/A',
#   'white balance modes': 'Automatic, Daylight, Shade, Cloudy,Incandescent, Fluorescent (Warm White/ Cool White/Day White/Daylight), Flash, Color temperature/Color filter, Custom'},
#  '66': {'<page title>': 'NIKON COOLPIX S02 SILVER 13.2MP 3X 2.7"LCD 32176',
#   'ac power adapter': 'EH-70P',
#   'additional zoom': 'N/A',
#   'approx resolution': '13MP',
#   'aspect ratio': 'N/A',
#   'battery': 'Built-in',
#   'builtin flash': 'Yes',
#   'builtin memory': '7.3 GB',
#   'burst rate': 'N/A',
#   'camera type': 'Small & Easy',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Silver',
#   'connectivity': 'Audio/video (A/V) output, Digital I/O (USB) , HDMI micro connector D',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'Touch TFT LCD',
#   'dustproof': 'No',
#   'effective pixels': '13.2MP',
#   'exposure modes': 'Programmed auto exposure; Exposure compensation (-2.0 to +2.0 EV in steps of 1/3 EV)',
#   'external flash connection': 'No',
#   'file formats': 'Still: JPEG; Movies: MOV',
#   'flash modes': 'TTL auto flash with monitor preflashes',
#   'image stabilization': 'N/A',
#   'iso sensitivity': '125-1600',
#   'lens': 'NIKKOR glass lens, 6 elements in 5 groups, 4.1-12.3mm (35mm equivalent: 30-90mm), f/3.3-5.9',
#   'memory card type': 'N/A',
#   'metering method': 'Matrix, Centre-weighted (digital zoom less than 2x), Spot (digital zoom 2X or more)',
#   'operatingstorage temperature': '0 to 40C (32 to 104F); Humidity: 0-85%',
#   'optical zoom': '3x',
#   'remote control': 'N/A',
#   'screen size': '2.7"',
#   'self timer': '10 sec.',
#   'sensor typesize': '1/3.1" CMOS',
#   'shockproof': 'No',
#   'shutter': 'Mechanical and CMOS electronic shutter: 1sec. - 1/2000 sec.',
#   'viewfinder type': 'N/A',
#   'waterproofing': 'No',
#   'white balance modes': 'Auto'},
#  '211': {'<page title>': 'CANON POWERSHOT SX700HS RED 16.1MP 30X W/CASE 9339B015',
#   'ac power adapter': 'ACK-DC40',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': '16:9, 3:2, 4:3, 1:1',
#   'battery': 'NB-6LH',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': '3.1 shots/sec.; 8.5 shots/sec.',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Red',
#   'connectivity': 'HDMI micro connector',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '112.7 x 65.8 x 34.8mm (4.44 x 2.59 x 1.37 in.)',
#   'display screen type': 'TFT Colour',
#   'dustproof': 'No',
#   'effective pixels': '16.1MP',
#   'exposure modes': 'AE Lock',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, On, Slow Synchro, Off',
#   'focus range': 'Auto: 0.4 in. (1 cm) - infinity (W), 4.6 ft. (1.4 m) - infinity (T); Normal: 2.0 in. (5 cm) - infinity (W), 4.6 ft. (1.4 m) - infinity (T); Macro: 0.4 in. - 1.6 ft. (1 - 50 cm); Sports: 3.3 ft. (1 m) - infinity (W), 26.0 ft. (8m) - infinity (T)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-3200',
#   'lens': '4.5mm (W) - 135.0mm (T) (35mm film equivalent: 25-750mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Evaluative, Center-weighted average, Spot',
#   'operatingstorage temperature': '0-40C (32-104F)',
#   'optical zoom': '30x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec., 10 Sec., Custom',
#   'sensor typesize': '1/2.3" CMOS',
#   'shockproof': 'No',
#   'shutter': '15-1/3200 sec.',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '245g (8.64 oz.) Body Only',
#   'white balance modes': 'Auto, Daylight, Cloudy, Tungsten, Fluorescent, Fluorescent H, Custom, Multi-area White Balance'},
#  '7': {'<page title>': 'OLYMPUS SH-1 WHITE 16MP 24X 3" 60P FULLHD V107080WU000',
#   'ac power adapter': 'F-2AC',
#   'additional zoom': '2x',
#   'approx resolution': '16MP',
#   'aspect ratio': '3:2',
#   'battery': 'LI-92B',
#   'builtin flash': 'Yes',
#   'builtin memory': '37MB',
#   'burst rate': '2.5 fps; 11.5 fps; 20 fps; 60 fps',
#   'camera type': 'Super Zoom',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'White',
#   'connectivity': 'USB Connector, DC Jack, AV Output, HDMI Type D',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '108.8 x 63.2 x 42.4mm (4.3 x 2.5 x 1.7 in.)',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'No',
#   'effective pixels': '16.0MP',
#   'exposure modes': 'Intelligent Auto (iAUTO), Program Auto (P), Manual (M), Art Filters (11), Scene Modes (16), Hand-Held Starlight, Panorama, Photo Story, Advanced Movie',
#   'external flash connection': 'No',
#   'file formats': 'Still: JPEG; Video: MOV/H.264',
#   'flash modes': 'Auto, Red Eye Reduction, Fill-in, Off',
#   'focus range': 'Wide: 10cm/3.9in to infinity; Tele: 40cm/15.7in to infinity; Super Macro Mode: 3cm/1.2in to infinity, focal length fixed to 25mm (equiv)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '100-6400',
#   'lens': '4.5 - 108mm (35mm equivalent: 25 - 600mm)',
#   'memory card type': 'SD, SDHC, SDXC',
#   'metering method': 'NA',
#   'operatingstorage temperature': 'NA',
#   'optical zoom': '24x',
# ...
#   'digital zoom': '2x',
#   'dimensions wxhxd': '124.5 x 86.4 x 91.4 mm (4.9 x 3.4 x 3.6 in)',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'No',
#   'effective pixels': '16.2MP',
#   'exposure modes': 'Program AE',
#   'external flash connection': 'No',
#   'file formats': 'JPEG, MP4',
#   'flash modes': 'Auto, Auto & Red-eye reduction, Fill-in flash, Slow sync, Flash Off, Red-eye fix',
#   'focus range': 'Normal: 80cm -Infinity (Wide), 150cm-infinity(Tele), *Macro : 10cm-80cm (Wide), 150cm-350cm (Tele), *Auto Macro : 1cm-infinity (Wide), 150cm-infinity (Tele),*Super Macro : 1cm (Wide)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-3200',
#   'lens': '25mm',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Multi, Spot, Center-weighted, Face Detection AE',
#   'operatingstorage temperature': '0 to 40C (32 to 104F),\nHumidity: 5-85%',
#   'optical zoom': '35x',
#   'remote control': 'via Smartphone',
#   'screen size': '3.0"',
#   'self timer': '2 sec., 10 sec.',
#   'sensor typesize': 'CCD',
#   'shockproof': 'No',
#   'shutter': '8 - 1/2000 sec.',
#   'viewfinder type': 'TFT LCD Display',
#   'waterproofing': 'No',
#   'weight': '458.1 g (1.01 lb.)',
#   'white balance modes': 'Auto WB, Daylight, Cloudy, Fluorescent_H, Fluorescent_L, Tungsten, Custom, K'},
#  '102': {'<page title>': 'HASSELBLAD STELLAR SLV, OLIVE WOOD GRIP 3012618',
#   'ac power adapter': '3.6 V AC Adaptor AC-UD10/UD11, 5V',
#   'additional zoom': 'N/A',
#   'approx resolution': '20MP',
#   'aspect ratio': '16:9; 4:3',
#   'battery': 'NP-BX1',
#   'builtin flash': 'Yes',
#   'builtin memory': 'No',
#   'burst rate': 'N/A',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Silver w/ Olive Wood Grip',
#   'connectivity': 'HDMI micro jack, Micro USB (USB2.0)',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'N/A',
#   'display screen type': 'TFT LCD',
#   'dustproof': 'N/A',
#   'effective pixels': '20.2MP',
#   'exposure modes': 'Automatic exposure, Aperture priority, Shutter priority, Manual exposure, Scene Selection (13 modes)',
#   'external flash connection': 'No',
#   'file formats': 'Still: RAW, JPEG; Video: AVCHD, MPEG-4 AVC/H.264',
#   'flash modes': 'N/A',
#   'focus range': 'N/A',
#   'image stabilization': 'Yes',
#   'iso sensitivity': 'N/A',
#   'lens': 'Carl Zeiss Vario-Sonnar T*',
#   'memory card type': 'Memory Stick Duo media, Memory Stick Micro media, SD cards, microSD memory cards',
#   'metering method': 'N/A',
#   'operatingstorage temperature': 'Operating: 0 C to 40 C (32 F to 104 F); Storage: -20 C to 60 C (-4 F to 140 F)',
#   'optical zoom': '3.6x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': 'N/A',
#   'sensor typesize': '13.2 x 8.8 mm CMOS Sensor',
#   'shockproof': 'N/A',
#   'shutter': 'N/A',
#   'viewfinder type': 'N/A',
#   'warranty': 'Canadian Warranty: Two Years Parts & Labour',
#   'waterproofing': 'N/A',
#   'white balance modes': 'Automatic, Daylight, Shade, Cloudy,Incandescent, Fluorescent (Warm White/ Cool White/Day White/Daylight), Flash, Color temperature/Color filter, Custom'},
#  '40': {'<page title>': 'NIKON COOLPIX S6800 RED 16MP 12X 32182',
#   'ac power adapter': 'EH-71P (Included); EH-62G (Sold Separately)',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': 'NA',
#   'battery': 'EN-EL19',
#   'builtin flash': 'Yes',
#   'builtin memory': '25MB',
#   'burst rate': '9.4 fps',
#   'camera type': 'Small & Easy',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Red',
#   'connectivity': 'Micro USB; HDMI micro Connector (D)',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'dimensions wxhxd': '96.8mm x 57.5mm x 22.9mm (\n3.9 x 2.3 x 1 in.)',
#   'display screen type': 'LCD Screen',
#   'dustproof': 'No',
#   'effective pixels': '16.0MP',
#   'exposure modes': 'Programmed auto; Scene Auto Selector',
#   'external flash connection': 'No',
#   'file formats': 'JPEG; MOV',
#   'flash modes': 'TTL Auto',
#   'focus range': 'W: 50cm to infinity; T: 1.5m to infinity; Macro: 2cm to infinity',
#   'image stabilization': 'No',
#   'iso sensitivity': '125-6400',
#   'lens': '4.5-54.0mm (35mm equivalent: 25-300mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Centre-weighted, Matrix, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)',
#   'optical zoom': '12x',
#   'remote control': 'No',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.3" CCD',
#   'shockproof': 'No',
#   'shutter': '4 sec - 1/4000 sec',
#   'viewfinder type': 'LCD Display',
#   'waterproofing': 'No',
#   'weight': '145g (5.2 oz.)',
#   'white balance modes': 'Auto, Cloudy, Daylight, Flash, Fluorescent, Incandescent, Preset Manual'},
#  '205': {'1 star': '(2)',
#   '2 star': '(0)',
#   '3 star': '(1)',
#   '4 star': '(0)',
#   '5 star': '(1)',
#   '<page title>': 'OLYMPUS TG-2 IHS BLACK 12MP CMOS 4X 3"OLED V104120BU000',
#   'ac power adapter': 'F-2AC',
#   'additional zoom': 'None',
#   'approx resolution': '12MP',
#   'aspect ratio': '3:2',
#   'battery': 'LI-90B',
#   'builtin flash': 'Yes',
#   'builtin memory': '22MB',
#   'burst rate': 'Up to 5 fps at 12 MP for up to 25 frames\nUp to 15 fps at 3 MP for up to 100 frames\nUp to 60 fps at 3 MP for up to 100 frames',
#   'camera type': 'Waterproof',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, DC Input, HDMI D, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'OLED Rear Screen',
#   'dustproof': 'Yes',
#   'effective pixels': '12.0MP',
#   'exposure modes': 'Modes: Aperture Priority, Programmed Auto',
#   'external flash connection': 'N/A',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto\nFill-in\nOff\nLED\nRed-eye Reduction',
#   'focus range': 'Wide: 3.94" (10 cm) - Infinity\nTelephoto: 3.94" (10 cm) - Infinity\nSuper-Macro: 0.39" (1 cm) - 3.94" (10 cm)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '125-6400',
#   'lens': 'EFL: 4.5-18 mm (35 mm equivalent: 25-100 mm)\nAperture: f/2.0 (W) - 4.9 (T)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'N/A',
#   'operatingstorage temperature': '-10 to 40C (14 to 104F)\nHumidity: 0-85%',
#   'optical zoom': '4x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 sec, 12 sec',
#   'sensor typesize': '1/2.3" CMOS',
#   'shockproof': '7.0 ft.',
#   'shutter': '4-1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'waterproofing': '15.0m',
#   'white balance modes': 'N/A'},
#  '79': {'1 star': '(0)',
#   '2 star': '(0)',
#   '3 star': '(0)',
#   '4 star': '(1)',
#   '5 star': '(0)',
#   '<page title>': 'PANASONIC DMCF5K BLACK 14.1MP 5X 2.7" DMCF5K',
#   'ac power adapter': '110-240V AC',
#   'additional zoom': 'None',
#   'approx resolution': '14MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'Rechargeable Lithium Ion Battery Pack',
#   'builtin flash': 'Yes',
#   'builtin memory': '10MB',
#   'burst rate': 'N/A',
#   'camera type': 'Small & Easy',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'N/A',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'LCD Screen',
#   'effective pixels': '14.1MP',
#   'exposure modes': 'Program AE',
#   'external flash connection': 'N/A',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, Auto/Red-eye Reduction, Forced On, Slow Sync./Red-eye Reduction, Forced Off',
#   'focus range': 'Normal / Auto Scene: Wide 10 cm - infinity / Tele 100 cm - infinity',
#   'image stabilization': 'N/A',
#   'iso sensitivity': '100-6400',
#   'lens': 'f=5 - 25 mm (28 - 140 mm in 35 mm equiv.) (34 - 170mm in 35mm equiv. in video recording)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'N/A',
#   'operatingstorage temperature': 'N/A',
#   'optical zoom': '5x',
#   'remote control': 'N/A',
#   'screen size': '2.7"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/2.33" CCD',
#   'shutter': '8-1/2000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'white balance modes': 'Auto / Daylight / Cloudy / Shade / Incandescent / White Set'},
#  '32': {'<page title>': 'FUJIFILM XQ1 BLACK 12MP 4X 3.0"LCD 600013201',
#   'ac power adapter': 'AC-5VT',
#   'additional zoom': 'None',
#   'approx resolution': '12MP',
#   'aspect ratio': 'NA',
#   'battery': 'NP-48 Li-ion Battery',
#   'builtin flash': 'Yes',
#   'builtin memory': '66MB',
#   'burst rate': '3 to 12 fps',
#   'camera type': 'Small & Easy',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'USB 2.0 High-Speed; HDMI Micro connector',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'TFT colour LCD monitor',
#   'dustproof': 'NA',
#   'effective pixels': '12MP',
#   'exposure modes': 'Programmed AE / Aperture Priority AE / Shutter Speed Priority AE / Manual exposure',
#   'external flash connection': 'None',
#   'file formats': 'JPEG, RAW; MOV',
#   'flash modes': 'Red-eye removal OFF: Auto / Forced Flash / Suppressed Flash / Slow Synchro.; Red-eye removal ON: Red-eye Reduction Auto / Red-eye Reduction & Forced Flash / Suppressed Flash / Red-eye Reduction & Slow Synchro. (* Red-eye removal is active when Face Detection is set to ON.)',
#   'focus range': 'Normal: Wide : Approx. 50cm / 1.6 ft. to infinity, Telephoto : Approx. 80cm / 2.6 ft. to infinity; Macro: Wide : Approx. 3cm - 3.0m / 1.1 in. - 9.8 ft., Telephoto : Approx. 50cm - 3.0m / 1.6 ft. - 9.8 ft.',
#   'image stabilization': 'Lens Shift type',
#   'iso sensitivity': '100-12800',
#   'lens': '6 Groups/7 Lenses',
#   'memory card type': 'SD / SDHC / SDXC',
#   'metering method': 'TTL 256-zone metering / Multi / Spot / Average',
#   'operatingstorage temperature': '0 to 40 degreesC',
#   'optical zoom': '4x',
#   'remote control': 'NA',
#   'screen size': '3.0 inch',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '2/3" X-Trans CMOS II',
#   'shockproof': 'NA',
#   'shutter': '30 sec. to 1/4000 sec.',
#   'viewfinder type': 'NA',
#   'waterproofing': 'NA',
#   'white balance modes': 'Automatic scene recognition; Custom / Colour temperature selection (K); Preset : Fine, Shade, Fluorescent light (Daylight), Fluorescent light (Warm White), Fluorescent light (Cool White), Incandescent light, Underwater, Custom, Colour temperature selection'},
#  '111': {'<page title>': 'PANASONIC DMC-LF1 12.1MP 7.1X 3" BLACK DMCLF1K',
#   'ac power adapter': 'N/A',
#   'additional zoom': '14.3x',
#   'approx resolution': '12MP',
#   'aspect ratio': '1:1, 3:2, 4:3, 16:9',
#   'battery': 'Rechargeable Lithium Ion Battery Pack',
#   'builtin flash': 'Yes',
#   'builtin memory': '87MB',
#   'burst rate': 'Up to 10 fps at 12.1 MP for up to 12 frames\nUp to 40 fps\nUp to 60 fps',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'AV Output, HDMI D, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'LCD Rear Screen',
#   'effective pixels': '12.1MP',
#   'exposure modes': 'Modes: Aperture Priority, Manual, Programmed Auto, Shutter Priority\nCompensation: -2 EV to +2 EV (in 1/3 EV steps)',
#   'external flash connection': 'N/A',
#   'file formats': 'JPEG, MPO, RAW',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nFlash On\nOff\nRed-eye Reduction\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Wide: 19.69" (50 cm) - Infinity\nTelephoto: 31.50" (80 cm) - Infinity\nWide Macro: 1.18" (3 cm) - Infinity\nTele Macro: 31.50" (80 cm) - Infinity',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-12800',
#   'lens': 'Leica DC Vario-Summicron, 10 elements in 8 groups\n4 Aspheric, 1 ED\nEFL: 6-42.8 mm (35 mm equivalent: 28-200 mm)\nAperture: f/2 (W) - 5.9 (T) to f/8',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi, Spot',
#   'operatingstorage temperature': 'N/A',
#   'optical zoom': '7.1x',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': '2 Sec, 10 Sec',
#   'sensor typesize': '1/1.7" MOS',
#   'shutter': '250-1/4000 sec',
#   'viewfinder type': 'Electronic, LCD Display',
#   'warranty': '1 year warranty',
#   'white balance modes': 'Auto, Cloudy, Custom, Daylight, Incandescent, Shade, White Set'},
#  '115': {'<page title>': 'CANON POWERSHOT S120 HS 12.1MP 5X WIDE ANGLE 3" WIFI 8407B005',
#   'ac power adapter': 'CA-DC10',
#   'additional zoom': 'None',
#   'approx resolution': '12 MP',
#   'aspect ratio': '16:9, 3:2, 4:3, 1:1, 4:5',
#   'battery': 'NB-6LH',
#   'builtin flash': 'Yes',
#   'builtin memory': 'N/A',
#   'burst rate': 'Up to 12.1 fps for up to 6 frames; Up to 9.4 fps for 7 or more frames',
#   'camera type': 'Wi-Fi',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Black',
#   'connectivity': 'Mini-HDMI',
#   'digital point and shoot camera': '.',
#   'digital zoom': '4x',
#   'display screen type': 'N/A',
#   'dustproof': 'N/A',
#   'effective pixels': '12.1MP',
#   'exposure modes': 'Manual Exposure, Program Shift, Safety Shift, AE Lock, Compensation: Still Images: +3 stops in 1/3-stop increments',
#   'external flash connection': 'None',
#   'file formats': 'JPEG',
#   'flash modes': 'Auto, Flash On, Slow Synchro, Flash Off',
#   'focus range': 'Normal: 2.0 in. (5cm) - infinity (W), 12 in. (30cm) - infinity (T); Auto/Manual: 1.2 in. (3cm) - infinity (W), 12 in. (30cm) - infinity (T); Macro AF: 1.2 in. - 1.6 ft. (3-50cm) (W), 12 in. - 1.6 ft. (30-50cm) (T); Quick: 4.9 - 66 ft. (1.5 - 20m) (W,T)',
#   'image stabilization': 'Yes',
#   'iso sensitivity': '80-12800',
#   'lens': '5.2 (W) - 26.0 (T) mm (35mm film equivalent: 24-120mm)',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Evaluative, Center-weighted average, Spot',
#   'operatingstorage temperature': '0-40C (32-104F); Humidity: 10-90%',
#   'optical zoom': '4x',
#   'remote control': 'None',
#   'screen size': '3.0"',
#   'self timer': '2 Sec., 10 Sec.',
#   'sensor typesize': '1/1.7" CMOS',
#   'shockproof': 'N/A',
#   'shutter': '1-1/2500 sec.',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'waterproofing': 'N/A',
#   'white balance modes': 'Auto, Daylight, Cloudy, Tungsten, Fluorescent, Fluorescent H, Flash, Underwater, Custom 1, Custom 2'},
#  '239': {'<page title>': 'RICOH GR LIMITED ED.(W/HOOD,STRAP,CASE) 175823',
#   'ac power adapter': 'AC-U1',
#   'additional zoom': 'None',
#   'approx resolution': '16MP',
#   'aspect ratio': '1:1, 3:2, 4:3',
#   'battery': 'DB-65',
#   'builtin flash': 'Yes',
#   'builtin memory': '54MB',
#   'burst rate': 'Up to 4 fps at 16 MP',
#   'camera type': 'Advanced',
#   'canon pixma pro1 pro10 or pro100 printer': '.',
#   'colour': 'Green',
#   'connectivity': 'AV Output, HDMI D, USB 2.0',
#   'digital point and shoot camera': '.',
#   'digital zoom': 'None',
#   'display screen type': 'LCD Rear Screen',
#   'dustproof': 'NA',
#   'effective pixels': '16.2MP',
#   'exposure modes': 'Modes: Aperture Priority, Auto, Bulb, Manual, Movie, My Settings, Programmed Auto, Shutter Priority, Shutter/Aperture Priority, Time\nMetering Range: EV 1.8 - EV 17.7\nCompensation: -4 EV to +4 EV (in 1/3 EV steps)',
#   'external flash connection': 'Hot Shoe',
#   'file formats': 'JPEG, RAW; Movie',
#   'flash modes': 'Auto\nAuto/Red-eye Reduction\nFlash On\nFlash On w/ Red-eye Reduction\nManual\nSlow Sync\nSlow Sync./Red-eye Reduction',
#   'focus range': 'Normal: 11.76" (29.87 cm) - Infinity;\nMacro: 3.9" (9.91 cm) - Infinity',
#   'image stabilization': 'None',
#   'iso sensitivity': '100-25600',
#   'lens': '7 elements in 5 groups\n2 Aspheric\nEFL: 18.3 mm (35 mm equivalent: 28 mm)\nAperture: f/2.8 to f/16',
#   'memory card type': 'SD/SDHC/SDXC',
#   'metering method': 'Center-weighted, Multi, Spot',
#   'operatingstorage temperature': '0 to 40C (32 to 104F)',
#   'optical zoom': 'None',
#   'remote control': 'N/A',
#   'screen size': '3.0"',
#   'self timer': 'N/A',
#   'sensor typesize': 'APS-C CMOS',
#   'shockproof': 'NA',
#   'shutter': 'Type: Electronic & Mechanical\nSpeed: 30 - 1/4000 sec',
#   'viewfinder type': 'LCD Display',
#   'warranty': '1 year warranty',
#   'waterproofing': 'NA',
#   'white balance modes': 'Auto, Cloudy, Daylight, Incandescent, Manual, Shade'}}

# %%
brands = set([x.lower() for x in brands])
models = set([x.lower() for x in models])

# %%
camera_ids = []
camera_brand = []
camera_model = []
camera_color = []
camera_resolution = []
camera_sensitivity = []
camera_stablization = []
camera_battery = []
camera_mpn = []
camera_title = []

for k, v in products['www.henrys.com'].items():
    camera_ids.append('www.henrys.com//'+k)
    brand = set([])
    model = set([])
    color = set([])
    resolution = set([])
    sensitivity = set([])
    stablization = set([])
    battery = set([])
    mpn = set([])
    titles = v['<page title>'].split(' ')
    for t in titles:
        if t.lower() in brands:
            brand.add(t)
    for step in range(3):
        for start in range(len(titles) - step):
            bbb = ' '.join(titles[start:start+step])
            if bbb.lower() in models:
                model.add(bbb)
    if 'brand' in v:
        brand.add(v['brand'])
    if 'manufacturer' in v:
        brand.add(v['manufacturer'])
    
    if 'model no' in v:
        model.add(v['model no'])
    if 'series' in v:
        model.add(v['series'])
    
    if 'colour' in v:
        if type(v['colour']) == list:
            for b in v['colour']:
                color.add(b)
        else:
            color.add(v['colour'])
    
    if 'battery' in v:
        if type(v['battery']) == list:
            for b in v['battery']:
                battery.add(b)
        else:
            battery.add(v['battery'])
        
    if 'effective pixels' in v:
        if type(v['effective pixels']) == list:
            for b in v['effective pixels']:
                resolution.add(b)
        else:
            resolution.add(v['effective pixels'])
            
    if 'approx resolution' in v:
        if type(v['approx resolution']) == list:
            for b in v['approx resolution']:
                resolution.add(b)
        else:
            resolution.add(v['approx resolution'])
        
    if 'iso sensitivity' in v:
        if type(v['iso sensitivity']) == list:
            for b in v['iso sensitivity']:
                sensitivity.add(b)
        else:
            sensitivity.add(v['iso sensitivity'])

    
    if 'image stabilization' in v:
        if type(v['image stabilization']) == list:
            for b in v['image stabilization']:
                stablization.add(b)
        else:
            stablization.add(v['image stabilization'])
    
    
    
    camera_brand.append(';'.join(brand))
    camera_model.append(';'.join(model))
    camera_color.append(';'.join(color))
    camera_resolution.append(';'.join(resolution))
    camera_sensitivity.append(';'.join(sensitivity))
    camera_stablization.append(';'.join(stablization))
    camera_battery.append(';'.join(battery))
    camera_mpn.append(';'.join(mpn))
    camera_title.append(v['<page title>'])
    
# 1                               WATERPROOF                         Blue
# 2                                    BLACK                        Black
# 3                 XP200;WATERPROOF;FINEPIX                       Yellow
# 4                                    BLACK                        Black
# 5                      WIFI;POWERSHOT;S200                        Black
# 6                          DP3;DP3 MERRILL                        Black
# 7                                 XF1;WIDE                        Brown
# 8                               BLACK;WIDE                        Black
# 9                      CAMERA;WB2200F;WIDE                        Black
# 10                         DMC-FZ200;BLACK                        Black
# 11                               POWERSHOT                        White
# 12                                    WIDE                       Silver
# 13                     COOLPIX;S3600;BLACK                        Black
# 14   VARIO;CAMERA;DIGITAL;X;DIGITAL CAMERA                        Black
# 15                                 6;D-LUX                        Black
# 16                             POWERSHOT;N                        White
# 17         COOLPIX;COOLPIX P600;P600;BLACK                        Black
# 18                        CAMERA;POWERSHOT                        Black
# 19                                DSC-W830                       Silver
# 20                               POWERSHOT                          Red
# 21                            WB250F;BLACK                        Black
# 22                                          Silver w/ Carbon Fiber Grip
# 23                          COOLPIX;3X;S02                       Silver
# 24                       SX700HS;POWERSHOT                          Red
# 25                            SH-1;OLYMPUS                        White
# 26                 COOLPIX;P520;BLACK;WIDE                        Black
# 27                      TG-3;OLYMPUS;1080P                          Red
# 28                              BLACK;WIDE                        Black
# 29                                   BLACK                        Black
# ..                                     ...                          ...
# 151                LCD;WIDE;OLYMPUS;VG-160                          Red
# 152                             WATERPROOF                          Red
# 153                                           Orange w/ Wenge Wood Grip
# 154                                COOLPIX                          Red
# 155                         WIFI;POWERSHOT                       Silver
# 156                     COOLPIX;WIDE;P7800                        Black
# 157                                          Silver w/ Walnut Wood Grip
# 158                              XP70;WIFI                         Blue
# 159                                  BLACK                        Black
# 160              COOLPIX;P600;COOLPIX P600                          Red
# 161                              DIGITAL;A
# 162                        POWERSHOT;BLACK                        Black
# 163                                                               White
# 164                                  BLACK                        Black
# 165            SP-820UZ;OLYMPUS;BLACK;WIDE                        Black
# 166                          WB350F;CAMERA                          Red
# 167                             WIFI;BLACK                        Black
# 168                     DP2 MERRILL;CAMERA                        Black
# 169                                  BLACK                        Black
# 170                               XF1;WIDE                          Red
# 171                                  BLACK                        Black
# 172                   WB1100F;CAMERA;BLACK                        Black
# 173                                           Silver w/ Olive Wood Grip
# 174                          COOLPIX;S6800                          Red
# 175                 TG-2 IHS;OLYMPUS;BLACK                        Black
# 176                                  BLACK                        Black
# 177                              BLACK;XQ1                        Black
# 178                          BLACK;DMC-LF1                        Black
# 179               WIFI;WIDE;POWERSHOT;S120                        Black
# 180                                     GR                        Green
#
#             camera_resolution camera_sensitivity camera_stablization  \
# 0                 12MP;12.2MP           80-25600                 Yes
# 1                 16MP;16.1MP           100-6400                 Yes
# 2                 20MP;20.1MP            80-3200                 Yes
# 3                 16MP;16.4MP           100-6400                 Yes
# 4                        16MP           100-6400                 Yes
# 5                 10.1MP;10MP            80-6400                 N/A
# 6                        46MP           100-6400                None
# 7    12.0 million pixels;12MP          100-12800                 Yes
# 8                 14MP;14.1MP           100-6400                 Yes
# 9                 16MP;16.4MP           100-6400                 Yes
# 10                12MP;12.1MP           100-6400                 Yes
# 11                16MP;16.0MP           100-3200                 Yes
# 12                18.1MP;18MP           100-6400                 Yes
# 13                20MP;20.1MP            80-3200                  No
# 14                16MP;16.2MP          100-12500                 N/A
# 15                10.1MP;10MP           80-12800                 N/A
# 16                12MP;12.1MP            80-6400                 Yes
# 17                16MP;16.1MP          100-12800                 Yes
# 18                16MP;16.0MP           100-3200                 Yes
# 19                20MP;20.1MP            80-3200                 Yes
# 20                16MP;16.0MP           100-1600                 Yes
# 21                14MP;14.2MP            80-3200                 Yes
# 22                20.2MP;20MP                N/A                 Yes
# 23                13.2MP;13MP           125-1600                 N/A
# 24                16MP;16.1MP           100-3200                 Yes
# 25                16MP;16.0MP           100-6400                 Yes
# 26                18.1MP;18MP           80-12800                 Yes
# 27                16MP;16.0MP           100-6400                 Yes
# 28                20MP;20.1MP           100-3200                 Yes
# 29                20MP;20.1MP            80-3200                 Yes
# ..                        ...                ...                 ...
# 151               14MP;14.0MP            80-1600                 N/A
# 152               16MP;16.1MP           100-6400                 Yes
# 153               20.2MP;20MP                N/A                 Yes
# 154               20MP;20.1MP            80-3200                  No
# 155               16MP;16.0MP           100-3200                 Yes
# 156               12MP;12.2MP            80-6400                 N/A
# 157               20.2MP;20MP                N/A                 Yes
# 158               16MP;16.4MP           100-6400
# 159               16MP;16.0MP           100-3200                  No
# 160               16MP;16.1MP          100-12800                 Yes
# 161
# 162             16 MP;16.1 MP           100-3200                 Yes
# 163               18.2MP;18MP           80-12800                 Yes
# 164                      20MP           100-6400                 Yes
# 165               14MP;14.0MP            80-6400                 Yes
# 166               16MP;16.3MP                 NA                 Yes
# 167               20MP;20.4MP           80-12800                 Yes
# 168                      46MP                N/A                None
# 169                      16MP           100-3200                 Yes
# 170  12.0 million pixels;12MP          100-12800                 Yes
# 171               18.2MP;18MP           80-12800                 Yes
# 172               16MP;16.2MP            80-3200                 Yes
# 173               20.2MP;20MP                N/A                 Yes
# 174               16MP;16.0MP           125-6400                  No
# 175               12.0MP;12MP           125-6400                 Yes
# 176               14MP;14.1MP           100-6400                 N/A
# 177                      12MP          100-12800     Lens Shift type
# 178               12MP;12.1MP           80-12800                 Yes
# 179              12 MP;12.1MP           80-12800                 Yes
# 180               16MP;16.2MP          100-25600                None
#
#                                         camera_battery camera_mpn  \
# 0                                              EN-EL12
# 1                Rechargeable Lithium Ion Battery Pack
# 2                                           AA Battery
# 3                                                NP-50
# 4    Li-ion Battery Pack (3.6 V, 690 mAh, 2.5 Wh) (...
# 5                                               NB-6LH
# 6                                                BP-41
# 7                                               NP-50A
# 8                Rechargeable Lithium Ion Battery Pack
# 9                                              BP-1410
# 10               Rechargeable Lithium Ion Battery Pack
# 11                                        NB-6L/NB-6LH
# 12                                                  NA
# 13                                             EN-EL19
# 14                                              BP-DC8
# 15               Rechargeable Lithium Ion Battery Pack
# 16                                               NB-9L
# 17                                             EN-EL23
# 18                                              NB-6LH
# 19                                               NP-BN
# 20                                      NB-11L/NB-11LH
# 21                                             SLB-10A
{'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S3600 Digital Camera (Pink) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Pink',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA554E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '302': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Nikon Coolpix S6800 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '300',
#   'lens wide mm': '25',
#   'mpn': 'VNA521E1',
#   'optical zoom': '23',
#   'optical zoom range': '18x and higher'},
#  '45': {'35mm equivalent': '23-483',
#   '<page title>': 'Samsung WB350F Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '483',
#   'lens wide mm': '23',
#   'mpn': 'EC-WB350FBPBE1',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '265': {'35mm equivalent': '20-1200mm',
#   '<page title>': 'Panasonic Lumix FZ72 + DMW-LT55E + DMW-LA8 Kit | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nManual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': '3.0"',
#   'lens tele mm': '2040',
#   'lens wide mm': '20',
#   'mpn': 'DMC-FZ72LENSKIT',
#   'optical zoom': '102x',
#   'optical zoom range': '18x and higher'},
#  '42': {'35mm equivalent': '28-224mm',
#   '<page title>': 'Canon Ixus 140 HS Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Silver',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '224',
#   'lens wide mm': '28',
#   'mpn': '8195B010AA',
#   'optical zoom': '5x',
#   'optical zoom range': '4x to 7x'},
#  '151': {'35mm equivalent': '24-720mm',
#   '<page title>': 'Sony Cybershot HX60V Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Wide-Angle\nGPS\n3D Mode',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '720',
#   'lens wide mm': '24',
#   'mpn': 'DSCHX60V/B',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '291': {'35mm equivalent': '24-1000mm',
#   '<page title>': 'Nikon Coolpix P530 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '1000',
#   'lens wide mm': '24',
#   'mpn': 'VNA640E1',
#   'optical zoom': '42',
#   'optical zoom range': '18x and higher'},
#  '257': {'35mm equivalent': '25-450mm',
#   '<page title>': 'Canon Powershot SX600 HS Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '450',
#   'lens wide mm': '25',
#   'mpn': '9342B011',
#   'optical zoom': '18',
#   'optical zoom range': '18x and higher'},
#  '248': {'35mm equivalent': '24-480mm',
#   '<page title>': 'Panasonic Lumix TZ55 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '480',
#   'lens wide mm': '24',
#   'mpn': 'DMC-TZ55EB-K',
#   'optical zoom': '20',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '293': {'35mm equivalent': '24-110mm',
#   '<page title>': 'Nikon Coolpix AW120 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': 'VNA311E1',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '18m'},
#  '153': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Sony Cybershot HX400v Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '20.4 Megapixels',
#   'colour': 'Black',
#   'features': 'Super-Zoom\nVari-Angle LCD',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'DSCHX400VB.CEH',
#   'optical zoom': '50',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '261': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S02 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '13 Megapixels',
#   'colour': 'Silver',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '90',
#   'lens wide mm': '30',
#   'mpn': 'VNA450E1',
#   'optical zoom': '3',
#   'optical zoom range': '4x or less'},
#  '233': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Panasonic Lumix FT25 Digital Camera (Blue) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Blue',
#   'features': 'Waterproof',
#   'hd video': 'HD (720P)',
#   'included lens': '4x to 7x',
#   'lcd size': '3.0"',
#   'lens tele mm': '100mm',
#   'lens wide mm': '25mm',
#   'mpn': 'DMC-FT25EB-A',
#   'optical zoom': '4x',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '7m'},
#  '214': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Nikon Coolpix S6400 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16.0 Megapixels',
#   'colour': 'Silver',
#   'features': 'Slimline\nWide-Angle',
#   'hd video': 'Full HD (1080p)',
#   'included lens': '12x 17x',
#   'lcd size': '3.0"',
#   'lens tele mm': '300',
#   'lens wide mm': '25',
#   'mpn': 'VNA190E1',
#   'optical zoom': '12',
#   'optical zoom range': '12x to 17x'},
#  '282': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Canon Powershot SX50 HS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Black',
#   'features': 'Semi-Pro\nSuper-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '24-1200mm',
#   'lcd size': '2.8"',
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': '6352B012AA',
#   'optical zoom': '50',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '268': {'35mm equivalent': '24-1008mm',
#   '<page title>': 'Canon Powershot SX520 HS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '1008',
#   'lens wide mm': '24',
#   'mpn': '9544B002',
#   'optical zoom': '42',
#   'optical zoom range': '18x and higher'},
#  '306': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Fuji Finepix S9200 Black (White Boxed) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': '3.0"',
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'P10NC12610A',
#   'optical zoom': '50',
#   'optical zoom range': '18x and higher'},
#  '280': {'35mm equivalent': '25-600mm',
#   '<page title>': 'Olympus SH-1 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '600',
#   'lens wide mm': '25',
#   'mpn': 'V107080BE00',
#   'optical zoom': '24',
#   'optical zoom range': '18x and higher'},
#  '152': {'35mm equivalent': '26-130mm',
#   '<page title>': 'Sony Cybershot TX30 Digital Camera (Blue) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '18 Megapixels',
#   'colour': 'Blue',
#   'features': '3D Mode\nSlimline\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '130',
#   'lens wide mm': '26',
#   'mpn': 'DSCTX30L.CE3',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x'},
#  '47': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Ricoh WG-4 GPS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Ricoh',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'GPS\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '25',
#   'mpn': '08541',
#   'optical zoom': '4x',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '14m'},
#  '252': {'35mm equivalent': '22-580mm',
#   '<page title>': 'Pentax Optio X5 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Pentax',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '580',
#   'lens wide mm': '22',
#   'mpn': '12762',
#   'optical zoom': '26',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '285': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Canon Ixus 265 HS Digital Camera (Purple) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Purple',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '25-300',
#   'mpn': '9351B007AA',
#   'optical zoom': '12x',
#   'optical zoom range': '12x to 17x'},
#  '219': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S9600 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '550',
#   'lens wide mm': '25',
#   'mpn': 'VNA502E1',
#   'optical zoom': '22',
#   'optical zoom range': '18x and higher'},
#  '165': {'35mm equivalent': '28-100mm',
#   '<page title>': 'Sony Cybershot DSC-RX100 III Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '20.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '100',
#   'lens wide mm': '28',
#   'mpn': 'DSCRX100M3.CEH',
#   'optical zoom': '3.6',
#   'optical zoom range': '4x or less',
#   'variangle lcd': 'Yes'},
#  '223': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Nikon Coolpix S6800 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '300',
#   'lens wide mm': '25',
#   'mpn': 'VNA522E1',
#   'optical zoom': '23',
#   'optical zoom range': '18x and higher'},
#  '238': {'35mm equivalent': '23-483',
#   '<page title>': 'Samsung Galaxy 2 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'lcd size': '4.8"',
#   'lens tele mm': '483',
#   'lens wide mm': '23',
#   'mpn': 'EK-GC200ZKABTU',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '166': {'35mm equivalent': '26-130mm',
#   '<page title>': 'Sony Cybershot TX30 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '18 Megapixels',
#   'colour': 'Black',
#   'features': '3D Mode\nSlimline\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '130',
#   'lens wide mm': '26',
#   'mpn': 'DSC-TX30/B',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x'},
#  '36': {'35mm equivalent': '23-483',
#   '<page title>': 'Samsung Galaxy 2 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'lcd size': '4.8"',
#   'lens tele mm': '483',
#   'lens wide mm': '23',
#   'mpn': 'EK-GC200ZWABTU',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '255': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S3600 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA551E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '307': {'35mm equivalent': '24-110mm',
#   '<page title>': 'Nikon Coolpix AW120 Digital Camera (Orange) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Orange',
#   'features': 'Compact\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': 'VNA592E1',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '18m'},
#  '41': {'35mm equivalent': '28-224mm',
#   '<page title>': 'Canon Ixus 140 HS Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '224',
#   'lens wide mm': '28',
#   'mpn': '8198B006AA',
#   'optical zoom': '5x',
#   'optical zoom range': '4x to 7x'},
#  '225': {'35mm equivalent': '25-750mm',
#   '<page title>': 'Nikon Coolpix S9700 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom\nWide-Angle\nWi-Fi',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '750',
#   'lens wide mm': '25',
#   'mpn': 'VNA650E1',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '52': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Nikon Coolpix S6400 Digital Camera (Purple) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16.0 Megapixels',
#   'colour': 'Purple',
#   'features': 'Slimline\nWide-Angle',
#   'hd video': 'Full HD (1080p)',
#   'included lens': '12x 17x',
#   'lcd size': '3.0"',
#   'lens tele mm': '300',
#   'lens wide mm': '25',
#   'mpn': 'VNA194E1',
#   'optical zoom': '12',
#   'optical zoom range': '12x to 17x'},
#  '276': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Nikon Coolpix S6800 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '300',
#   'lens wide mm': '25',
#   'mpn': 'VNA520E1',
#   'optical zoom': '23',
#   'optical zoom range': '18x and higher'},
#  '38': {'35mm equivalent': '25-750mm',
#   '<page title>': 'Canon Powershot SX700 HS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '750',
#   'lens wide mm': '25',
#   'mpn': '9338B014AA',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '216': {'35mm equivalent': '28-128mm',
#   '<page title>': 'Panasonic Lumix FT5 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Black',
#   'features': 'GPS\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '4x to 7x',
#   'lcd size': '3.0"',
#   'lens tele mm': '128mm',
#   'lens wide mm': '28mm',
#   'mpn': 'DMC-FT5EB-K',
#   'optical zoom': '4.6x',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '13m'},
#  '159': {'35mm equivalent': '35mm',
#   '<page title>': 'Sony Cybershot DSC-RX1R Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '24.3 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens wide mm': '35mm',
#   'mpn': 'DSCRX1R/B',
#   'optical zoom': 'n/a',
#   'variangle lcd': 'No'},
#  '170': {'35mm equivalent': '26-130mm',
#   '<page title>': 'Sony Cybershot TX30 Digital Camera (Orange) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '18 Megapixels',
#   'colour': 'Orange',
#   'features': 'Wide-Angle\n3D Mode\nSlimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '130',
#   'lens wide mm': '26',
#   'mpn': 'DSCTX30D.CE3',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x'},
#  '305': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S02 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '13 Megapixels',
#   'colour': 'White',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '90',
#   'lens wide mm': '30',
#   'mpn': 'VNA451E1',
#   'optical zoom': '3',
#   'optical zoom range': '4x or less'},
#  '250': {'35mm equivalent': '24-120mm',
#   '<page title>': 'Panasonic Lumix LX100 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '12.8 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle\nSemi-Pro',
#   'hd video': '4K HD',
#   'lcd size': "3.0''",
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': 'DMC-LX100EBK',
#   'optical zoom': '3.1',
#   'optical zoom range': '4x or less',
#   'variangle lcd': 'No'},
#  '215': {'35mm equivalent': '24-480mm',
#   '<page title>': 'Panasonic Lumix TZ55 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '480',
#   'lens wide mm': '24',
#   'mpn': 'DMC-TZ55EB-R',
#   'optical zoom': '20',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '297': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S3600 Digital Camera (Blue) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA551E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '279': {'35mm equivalent': '24-288mm',
#   '<page title>': 'Panasonic Lumix SZ8 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '288',
#   'lens wide mm': '24',
#   'mpn': 'DMC-SZ8EB-K',
#   'optical zoom': '12',
#   'optical zoom range': '12x to17x'},
#  '294': {'35mm equivalent': '21-105mm',
#   '<page title>': 'Olympus TG-850 Tough Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '105',
#   'lens wide mm': '21',
#   'mpn': 'V104150SE00',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '10m'},
#  '256': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S5300 Digital Camera (Plum) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Plum',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA542E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '277': {'<page title>': 'Ricoh GR Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Ricoh',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Semi-Pro',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'mpn': '175749'},
#  '236': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S02 Digital Camera (Blue) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '13 Megapixels',
#   'colour': 'Blue',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '90',
#   'lens wide mm': '30',
#   'mpn': 'VNA453E1',
#   'optical zoom': '3',
#   'optical zoom range': '4x or less'},
#  '273': {'35mm equivalent': '28-140mm',
#   '<page title>': 'Canon Powershot G16 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '12.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Semi-Pro',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '140',
#   'lens wide mm': '28',
#   'mpn': '8406B012AA',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x'},
#  '281': {'35mm equivalent': '25-600mm',
#   '<page title>': 'Olympus SH-1 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Silver',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '600',
#   'lens wide mm': '25',
#   'mpn': 'V107080SE00',
#   'optical zoom': '24',
#   'optical zoom range': '18x and higher'},
#  '235': {'35mm equivalent': '25-750mm',
#   '<page title>': 'Nikon Coolpix S9700 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom\nWi-Fi\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '750',
#   'lens wide mm': '25',
#   'mpn': 'VNA652E1',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '178': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Fuji Finepix S9200 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.2 Megapixels',
#   'colour': 'White',
#   'features': 'Manual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': "3.0''",
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'P10NC12720A',
#   'optical zoom': '50',
#   'optical zoom range': '18x and higher'},
#  '242': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S9600 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '550',
#   'lens wide mm': '25',
#   'mpn': 'VNA501E1',
#   'optical zoom': '22',
#   'optical zoom range': '18x and higher'},
#  '288': {'35mm equivalent': '24-120mm',
#   '<page title>': 'Canon Powershot S120 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0\\"',
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': '8407B012AA',
#   'optical zoom': '5',
#   'variangle lcd': 'No'},
#  '269': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S6700 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA660E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '292': {'35mm equivalent': '25-450mm',
#   '<page title>': 'Canon Powershot SX600 HS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '450',
#   'lens wide mm': '25',
#   'mpn': '9340B011',
#   'optical zoom': '18',
#   'optical zoom range': '18x and higher'},
#  '299': {'35mm equivalent': '24-120mm',
#   '<page title>': 'Nikon Coolpix P340 (White) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '12 Megapixels',
#   'colour': 'White',
#   'features': 'Compact\nHigh-Speed Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '100',
#   'lens wide mm': '24',
#   'mpn': 'VNA491E1',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x'},
#  '130': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Fuji Finepix S1 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.0 Megapixels',
#   'colour': 'Black',
#   'features': 'Super-Zoom\nWide-Angle\nRaw Shooting',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': "3.0''",
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'P10NC12730A',
#   'optical zoom': '50x',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': '18x and higher'},
#  '44': {'35mm equivalent': '28-140mm',
#   '<page title>': 'Ricoh WG20 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Ricoh',
#   'camera resolution': '14 Megapixels',
#   'colour': 'White',
#   'features': 'Waterproof',
#   'hd video': 'HD (720P)',
#   'lcd size': '2.7"',
#   'lens tele mm': '140',
#   'lens wide mm': '28',
#   'mpn': '08061',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '10m'},
#  '295': {'35mm equivalent': '23mm',
#   '<page title>': 'Fuji X100S Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.8''",
#   'lens tele mm': '23',
#   'lens wide mm': '23',
#   'mpn': 'P10NC09330A'},
#  '274': {'35mm equivalent': '20-1200mm',
#   '<page title>': 'Panasonic Lumix FZ72 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nRaw Shooting\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': '3.0"',
#   'lens tele mm': '1200',
#   'lens wide mm': '20',
#   'optical zoom': '60x',
#   'optical zoom range': '18x and higher'},
#  '227': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S3600 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA551E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '226': {'35mm equivalent': '24-240mm',
#   '<page title>': 'Canon Ixus 155 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'HD (720p)',
#   'lcd size': '2.7"',
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': '9357B006',
#   'optical zoom': '10x',
#   'optical zoom range': '8x to 11x'},
#  '133': {'35mm equivalent': '28-140mm',
#   '<page title>': 'Canon Powershot D30 (Blue) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Blue',
#   'features': 'Waterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"\'',
#   'lens tele mm': '140',
#   'lens wide mm': '28',
#   'mpn': '9337B012AA',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '25m'},
#  '270': {'35mm equivalent': '28-128mm',
#   '<page title>': 'Panasonic Lumix FT5 Digital Camera (Orange) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Orange',
#   'features': 'GPS\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '4x to 7x',
#   'lcd size': '3.0\\\\\\"',
#   'lens tele mm': '128mm',
#   'lens wide mm': '28mm',
#   'mpn': 'DMC-FT5EB-D',
#   'optical zoom': '4.6x',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '13m'},
#  '271': {'35mm equivalent': '28-128mm',
#   '<page title>': 'Panasonic Lumix FT5 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Silver',
#   'features': 'GPS\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '4x to 7x',
#   'lcd size': '3.0',
#   'lens tele mm': '128mm',
#   'lens wide mm': '28mm',
#   'mpn': 'DMC-FT5EB-S',
#   'optical zoom': '4.6x',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '13m'},
#  '176': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Fuji Finepix S9200 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': '3.0"',
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'P10NC12710A',
#   'optical zoom': '50',
#   'optical zoom range': '18x and higher'},
#  '232': {'35mm equivalent': '28-200mm',
#   '<page title>': 'Panasonic Lumix DMC-LF1 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '12.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '200',
#   'lens wide mm': '28',
#   'mpn': 'DMC-LF1EB-K',
#   'optical zoom': '7.1',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No'},
#  '254': {'35mm equivalent': '25-400mm',
#   '<page title>': 'Panasonic Lumix FZ1000 4K Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '20.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nManual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': '4K HD',
#   'included lens': '18x and higher',
#   'lcd size': '3.0"',
#   'lens tele mm': '400',
#   'lens wide mm': '25',
#   'mpn': 'DMC-FZ1000EB',
#   'optical zoom': '16',
#   'optical zoom range': '12x to 17x'},
#  '54': {'35mm equivalent': '28-140mm',
#   '<page title>': 'Fuji Finepix XP70 Digital Camera (Orange) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.4 Megapixels',
#   'colour': 'Orange',
#   'features': 'Compact\nWaterproof\nWifi',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '140',
#   'lens wide mm': '28',
#   'mpn': 'P10NC12620A',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '6m'},
#  '53': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Olympus Stylus Tough TG-3 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact\nExtreme Sports\nShockproof\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '4x to 7x',
#   'lcd size': '3.0"',
#   'lens tele mm': '100mm',
#   'lens wide mm': '25mm',
#   'mpn': 'V104140BE000',
#   'optical zoom': '4',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '15m'},
#  '158': {'35mm equivalent': '28-100mm',
#   '<page title>': 'Sony Cybershot DSC-RX100 II Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '20.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '100',
#   'lens wide mm': '28',
#   'mpn': 'DSCRX100M2CDN.YG',
#   'optical zoom': '3.6',
#   'optical zoom range': '4x or less',
#   'variangle lcd': 'Yes'},
#  '35': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S6700 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Red',
#   'features': 'Slimline',
#   'hd video': 'HD (720P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA661E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '258': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Fuji Finepix S9200 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': '3.0"',
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'P10NC12610A',
#   'optical zoom': '50',
#   'optical zoom range': '18x and higher'},
#  '167': {'35mm equivalent': '28-100mm',
#   '<page title>': 'Sony Cybershot RX100 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '20.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '100',
#   'lens wide mm': '28',
#   'mpn': 'DSCRX100.CEH',
#   'optical zoom': '3.6',
#   'optical zoom range': '4x or less',
#   'variangle lcd': 'No'},
#  '284': {'35mm equivalent': '24-1440mm',
#   '<page title>': 'Nikon Coolpix P600 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Wi-Fi',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '1440',
#   'lens wide mm': '24',
#   'mpn': 'VNA480E1',
#   'optical zoom': '60x',
#   'optical zoom range': '18x and higher'},
#  '243': {'35mm equivalent': '21-105mm',
#   '<page title>': 'Olympus TG-850 Tough Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Silver',
#   'features': 'Compact\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '105',
#   'lens wide mm': '21',
#   'mpn': 'V104150BE000',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '10m'},
#  '46': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Olympus Stylus Tough TG-3 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact\nExtreme Sports\nShockproof\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '4x to 7x',
#   'lcd size': '3.0"',
#   'lens tele mm': '100mm',
#   'lens wide mm': '25mm',
#   'mpn': 'V104120RE000',
#   'optical zoom': '4',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '15m'},
#  '234': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Canon Ixus 265 HS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '25-300',
#   'mpn': '8207B008AA',
#   'optical zoom': '12x',
#   'optical zoom range': '12x to 17x'},
#  '286': {'35mm equivalent': '24-120mm',
#   '<page title>': 'Nikon Coolpix P340 (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact\nHigh-Speed Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '100',
#   'lens wide mm': '24',
#   'mpn': 'VNA490E1',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x'},
#  '220': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Fuji Finepix S1 Black (White Boxed) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.0 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': "3.0''",
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'P10NC12730A',
#   'optical zoom': '50x',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': '18x and higher'},
#  '34': {'35mm equivalent': '24-90mm',
#   '<page title>': 'Panasonic Lumix LX7 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '10.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '90',
#   'lens wide mm': '24',
#   'mpn': 'DMC-LX5EB-K',
#   'optical zoom': '3.8',
#   'optical zoom range': '4x or less',
#   'variangle lcd': 'No'},
#  '308': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Ricoh WG-4 Digital Camera (Lime Yellow) | UK Digital Cameras',
#   'brand': 'Ricoh',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Yellow',
#   'features': 'Waterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '25',
#   'mpn': '08586',
#   'optical zoom': '4x',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '14m'},
#  '245': {'35mm equivalent': '23-481',
#   '<page title>': 'Samsung Galaxy GC100 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom\nGPS\nWide-Angle',
#   'lcd size': '4.8"',
#   'lens tele mm': '481',
#   'lens wide mm': '23',
#   'mpn': 'EK-GC100ZWABTU',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '240': {'<page title>': 'Nikon D3200 Digital SLR + 18-55mm VR Lens Kit | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '24.2 Megapixels',
#   'colour': 'Black',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'mpn': 'VBA330K001',
#   'variangle lcd': 'No'},
#  '221': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Fuji XQ1 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '25',
#   'mpn': 'P10NC11760A',
#   'optical zoom': '4'},
#  '39': {'35mm equivalent': '23-483',
#   '<page title>': 'Samsung WB350F Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '483',
#   'lens wide mm': '23',
#   'mpn': 'EC-WB350FBPWE1',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '231': {'35mm equivalent': '24-720mm',
#   '<page title>': 'Panasonic Lumix TZ60 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '18.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom\nWi-Fi',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '720',
#   'lens wide mm': '24',
#   'mpn': 'DMC-TZ60EB-K',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '289': {'<page title>': 'Sony Cybershot DSC-WX350 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '18.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'mpn': 'DSCWX350B.CEH',
#   'optical zoom': '20',
#   'optical zoom range': '18x and higher'},
#  '224': {'35mm equivalent': '24-110mm',
#   '<page title>': 'Nikon Coolpix AW120 Digital Camera (Camo) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Camo',
#   'features': 'Compact\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': 'VNA593E1',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '18m'},
#  '43': {'35mm equivalent': '24-720mm',
#   '<page title>': 'Canon Powershot SX400 IS Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1280 x 720p)',
#   'lcd size': "3.0''",
#   'lens tele mm': '720',
#   'lens wide mm': '24',
#   'mpn': '9769B002',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '272': {'35mm equivalent': '22-924mm',
#   '<page title>': 'Panasonic Lumix LZ40 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'HD (720P)',
#   'included lens': '18x and higher',
#   'lcd size': "3.0''",
#   'lens tele mm': '924',
#   'lens wide mm': '22',
#   'mpn': 'DMC-LZ40EB-K',
#   'optical zoom': '42x',
#   'optical zoom range': '18x and higher'},
#  '287': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Canon Ixus 265 HS Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Silver',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '25-300',
#   'mpn': '9348B007AA',
#   'optical zoom': '12x',
#   'optical zoom range': '12x to 17x'},
#  '259': {'35mm equivalent': '24-480mm',
#   '<page title>': 'Panasonic Lumix TZ55 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '480',
#   'lens wide mm': '24',
#   'mpn': 'DMC-TZ55EB-W',
#   'optical zoom': '20',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '222': {'35mm equivalent': '24-720mm',
#   '<page title>': 'Fuji FinePix S4800 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.0 Megapixels',
#   'colour': 'White',
#   'features': 'Manual Controls\nSemi-Pro\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '18x and higher',
#   'lcd size': "3.0''",
#   'lens tele mm': '720',
#   'lens wide mm': '24',
#   'mpn': 'P10NC09950A',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '278': {'35mm equivalent': '25-750mm',
#   '<page title>': 'Nikon Coolpix S9700 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact Super-Zoom\nWi-Fi\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '750',
#   'lens wide mm': '25',
#   'mpn': 'VNA651E1',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '127': {'<page title>': 'Canon EOS 700D SLR Camera + 18-55mm IS STM Lens (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '18 Megapixels',
#   'colour': 'Black',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'mpn': '8596B027AA',
#   'optical zoom range': 'n/a',
#   'variangle lcd': 'Yes'},
#  '260': {'35mm equivalent': '23-481',
#   '<page title>': 'Samsung Galaxy GC100 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Wide-Angle\nCompact Super-Zoom\nGPS',
#   'lcd size': '4.8"',
#   'lens tele mm': '481',
#   'lens wide mm': '23',
#   'mpn': 'EK-GC100ZKABTU',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '48': {'35mm equivalent': '28-224mm',
#   '<page title>': 'Canon Ixus 150 Digital Camera (Grey) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Grey',
#   'features': 'Slimline',
#   'hd video': 'HD (720p)',
#   'lcd size': '2.7"',
#   'lens tele mm': '224',
#   'lens wide mm': '28',
#   'mpn': '9145B006',
#   'optical zoom': '8x',
#   'optical zoom range': '8x to 11x'},
#  '267': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Canon Ixus 265 HS Digital Camera (Pink) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Pink',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '25-300',
#   'mpn': '9354B007AA',
#   'optical zoom': '12x',
#   'optical zoom range': '12x to 17x'},
#  '2': {'35mm equivalent': '21-1365mm',
#   '<page title>': 'Canon Powershot SX60 HS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Semi-Pro\nSuper-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'included lens': '21-1365mm',
#   'lcd size': '3.0"',
#   'lens tele mm': '1365',
#   'lens wide mm': '21',
#   'mpn': '9543B009AA',
#   'optical zoom': '65',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '230': {'35mm equivalent': '25-200mm',
#   '<page title>': 'Nikon Coolpix S5300 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '200',
#   'lens wide mm': '25',
#   'mpn': 'VNA291E1',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x'},
#  '237': {'35mm equivalent': '24-120mm',
#   '<page title>': 'Panasonic Lumix LX100 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '12.8 Megapixels',
#   'colour': 'Silver',
#   'features': 'Raw Shooting\nSemi-Pro\nWide-Angle',
#   'hd video': '4K HD',
#   'lcd size': "3.0''",
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': 'DMC-LX100EBS',
#   'optical zoom': '3.1',
#   'optical zoom range': '4x or less',
#   'variangle lcd': 'No'},
#  '266': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S02 Digital Camera (Pink) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '13 Megapixels',
#   'colour': 'Pink',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '90',
#   'lens wide mm': '30',
#   'mpn': 'VNA452E1',
#   'optical zoom': '3',
#   'optical zoom range': '4x or less'},
#  '161': {'35mm equivalent': '24-200mm',
#   '<page title>': 'Sony Cybershot RX10 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Sony',
#   'camera resolution': '20.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Super-Zoom\nVari-Angle LCD',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '200',
#   'lens wide mm': '24',
#   'mpn': 'DSCRX10.CEH',
#   'optical zoom': '8',
#   'optical zoom range': '8x to 11x',
#   'variangle lcd': 'Yes'},
#  '49': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Ricoh WG-4 GPS Digital Camera (Blue) | UK Digital Cameras',
#   'brand': 'Ricoh',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Blue',
#   'features': 'GPS\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '25',
#   'mpn': '08556',
#   'optical zoom': '4x',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '14m'},
#  '218': {'35mm equivalent': '25-450mm',
#   '<page title>': 'Canon Powershot SX600 HS Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '450',
#   'lens wide mm': '25',
#   'mpn': '9341B011',
#   'optical zoom': '18',
#   'optical zoom range': '18x and higher'},
#  '138': {'35mm equivalent': '24-100mm',
#   '<page title>': 'Canon PowerShot G7 X Digital Camera | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '20 Megapixels',
#   'colour': 'Black',
#   'features': 'Semi-Pro',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '24',
#   'mpn': '9546B009AA',
#   'optical zoom': '4',
#   'optical zoom range': '4x to 7x'},
#  '246': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Fuji XQ1 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Silver',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '25',
#   'mpn': 'P10NC11770A',
#   'optical zoom': '4'},
#  '253': {'35mm equivalent': '21-105mm',
#   '<page title>': 'Olympus TG-850 Tough Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '105',
#   'lens wide mm': '21',
#   'mpn': 'V104150WE000',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '10m'},
#  '217': {'35mm equivalent': '23-483',
#   '<page title>': 'Samsung WB350F Digital Camera (Brown) | UK Digital Cameras',
#   'brand': 'Samsung',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Brown',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '483',
#   'lens wide mm': '23',
#   'mpn': 'EC-WB350FBPNE1',
#   'optical zoom': '21',
#   'optical zoom range': '18x and higher'},
#  '51': {'35mm equivalent': '25-100mm',
#   '<page title>': 'Ricoh WG-4 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Ricoh',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Waterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '100',
#   'lens wide mm': '25',
#   'mpn': '08571',
#   'optical zoom': '4x',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No',
#   'waterproof depth': '14m'},
#  '55': {'35mm equivalent': '28-112mm',
#   '<page title>': 'Fuji FinePix X30 Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Silver',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '112',
#   'lens wide mm': '28',
#   'mpn': 'P10NC13280A'},
#  '229': {'35mm equivalent': '25-300mm',
#   '<page title>': 'Nikon Coolpix S6800 Digital Camera (Pink) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Pink',
#   'features': 'Slimline',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '300',
#   'lens wide mm': '25',
#   'mpn': 'VNA523E1',
#   'optical zoom': '23',
#   'optical zoom range': '18x and higher'},
#  '303': {'35mm equivalent': '25-550mm',
#   '<page title>': 'Nikon Coolpix S9600 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '550',
#   'lens wide mm': '25',
#   'mpn': 'VNA500E1',
#   'optical zoom': '22',
#   'optical zoom range': '18x and higher'},
#  '37': {'35mm equivalent': '28-112mm',
#   '<page title>': 'Fuji FinePix X30 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '12 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '112',
#   'lens wide mm': '28',
#   'mpn': 'P10NC13270A'},
#  '50': {'35mm equivalent': '25-750mm',
#   '<page title>': 'Canon Powershot SX700 HS Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '750',
#   'lens wide mm': '25',
#   'mpn': '9339B014AA',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '290': {'35mm equivalent': '24-720mm',
#   '<page title>': 'Canon Powershot SX400 IS Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1280 x 720p)',
#   'lcd size': "3.0''",
#   'lens tele mm': '720',
#   'lens wide mm': '24',
#   'mpn': '9545B002',
#   'optical zoom': '30',
#   'optical zoom range': '18x and higher'},
#  '300': {'35mm equivalent': '24-1248mm',
#   '<page title>': 'Pentax XG-1 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Pentax',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '1248',
#   'lens wide mm': '24',
#   'mpn': '07987',
#   'optical zoom': '52',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'No'},
#  '144': {'35mm equivalent': '24-120mm',
#   '<page title>': 'Canon PowerShot G1X Mark II (Black) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '12.8 Megapixels',
#   'colour': 'Black',
#   'features': 'Semi-Pro',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '120',
#   'lens wide mm': '24',
#   'mpn': '9167B012AA',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'Yes'},
#  '228': {'35mm equivalent': '24-1440mm',
#   '<page title>': 'Nikon Coolpix P600 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '16.1 Megapixels',
#   'colour': 'Red',
#   'features': 'Wi-Fi',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '1440',
#   'lens wide mm': '24',
#   'mpn': 'VNA481E1',
#   'optical zoom': '60x',
#   'optical zoom range': '18x and higher'},
#  '241': {'35mm equivalent': '24-1200mm',
#   '<page title>': 'Olympus SP-100EE Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Macro Mode',
#   'hd video': 'Full HD (1080p)',
#   'lcd size': '3.0"',
#   'lens tele mm': '1200',
#   'lens wide mm': '24',
#   'mpn': 'V103070BE000',
#   'optical zoom': '50x',
#   'optical zoom range': '18x and higher'},
#  '262': {'35mm equivalent': '28-224mm',
#   '<page title>': 'Canon Ixus 150 Digital Camera (Red) | UK Digital Cameras',
#   'brand': 'Canon',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Red',
#   'features': 'Slimline',
#   'hd video': 'HD (720p)',
#   'lcd size': '2.7"',
#   'lens tele mm': '224',
#   'lens wide mm': '28',
#   'mpn': '9148B006',
#   'optical zoom': '8x',
#   'optical zoom range': '8x to 11x'},
#  '301': {'35mm equivalent': '28-200mm',
#   '<page title>': 'Nikon Coolpix P7800 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Nikon',
#   'camera resolution': '12.2 Megapixels',
#   'colour': 'Black',
#   'features': 'Compact\nSemi-Pro',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'lens tele mm': '200',
#   'lens wide mm': '28',
#   'mpn': 'VNA670E1',
#   'optical zoom': '7.1',
#   'optical zoom range': '4x to 7x',
#   'variangle lcd': 'No'},
#  '298': {'35mm equivalent': '28-140mm',
#   '<page title>': 'Fuji Finepix XP70 Digital Camera (Blue) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.4 Megapixels',
#   'colour': 'Blue',
#   'features': 'Compact\nWifi\nWaterproof',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.7''",
#   'lens tele mm': '140',
#   'lens wide mm': '28',
#   'mpn': 'P10NC12630A',
#   'optical zoom': '5',
#   'optical zoom range': '4x to 7x',
#   'waterproof depth': '6m'},
#  '40': {'35mm equivalent': '23mm',
#   '<page title>': 'Fuji X100T Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.8''",
#   'lens tele mm': '23',
#   'lens wide mm': '23',
#   'mpn': 'P10NC13250A'},
#  '283': {'35mm equivalent': '23mm',
#   '<page title>': 'Fuji X100T Digital Camera (Silver) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16 Megapixels',
#   'colour': 'Silver',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "2.8''",
#   'lens tele mm': '23',
#   'lens wide mm': '23',
#   'mpn': 'P10NC13260A'},
#  '249': {'35mm equivalent': '25-600mm',
#   '<page title>': 'Panasonic Lumix FZ200 Digital Camera (Black) | UK Digital Cameras',
#   'brand': 'Panasonic',
#   'camera resolution': '12.1 Megapixels',
#   'colour': 'Black',
#   'features': 'Manual Controls\nSuper-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '600',
#   'lens wide mm': '25',
#   'mpn': 'DMC-FZ200EBK',
#   'optical zoom': '24',
#   'optical zoom range': '18x and higher',
#   'variangle lcd': 'Yes'},
#  '251': {'35mm equivalent': '25-600mm',
#   '<page title>': 'Olympus SH-1 Digital Camera (White) | UK Digital Cameras',
#   'brand': 'Olympus',
#   'camera resolution': '16 Megapixels',
#   'colour': 'White',
#   'features': 'Compact Super-Zoom',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': "3.0''",
#   'lens tele mm': '600',
#   'lens wide mm': '25',
#   'mpn': 'V107080WE000',
#   'optical zoom': '24',
#   'optical zoom range': '18x and higher'},
#  '239': {'<page title>': 'Fuji X-E2 Camera + 18-55mm Lens (Black) | UK Digital Cameras',
#   'brand': 'Fuji',
#   'camera resolution': '16.3 Megapixels',
#   'colour': 'Black',
#   'features': 'Raw Shooting\nWide-Angle',
#   'hd video': 'Full HD (1080P)',
#   'lcd size': '3.0"',
#   'mpn': 'P10NC11740A'}}

# %%
# brands = set([])
for i in products['www.ilgs.net'].values():
    if 'manufacturer' in i:
        print (i['manufacturer'])
        if type(i['manufacturer']) == list:
            brands.add(i['manufacturer'][0])
        else:
            brands.add(i['manufacturer'])
# Out:
# Canon
# Samsung
# Canon
# Panasonic
# Canon
# Canon
# Nikon
# Canon
# Canon
# Canon
# Canon
# Canon
# Samsung
# Pentax
# Sony
# Nikon
# Canon
# Sony
# Canon
# Sony
# Nikon
# Pentax
# Canon
# Nikon
# Canon
# Canon
# Panasonic
# Panasonic
# Pentax
# Fujifilm
# Canon
# Pentax
# Nikon
# Samsung
# Olympus
# Nikon
# Nikon
# Pentax
# Panasonic
# Nikon
# Sony
# Canon
# Nikon
# Ricoh
# Fujifilm
# Canon
# Canon
# Sony
# Sony
# Pentax
# Canon
# Fujifilm
# Pentax
# Canon
# Nikon
# Sony
# Sony
# Samsung
# Sony
# Canon
# Sony
# Samsung
# Olympus
# Samsung
# Olympus
# Olympus
# Canon
# Canon
# Sony
# Pentax
# Canon
# Sony
# Sony
# Panasonic
# Canon
# Nikon
# Canon
# Sony
# Samsung
# Sony
# Samsung
# Panasonic
# Canon
# Nikon
# Nikon
# Sony
# Pentax
# Nikon
# Ricoh
# Fujifilm
# Samsung
# Canon

# %%
brands
# Out:
# {'"EASY SHOT" CLIP',
#  '2000 IXLA',
#  '6.0 MP',
#  '6AVE',
#  'AEE',
#  'AEE Magicam',
#  'AKAI (Built by Samsung)',
#  'AUDIOVOX',
#  'AXESS',
#  'Action',
#  'Action Shot',
#  'Advancedplus',
#  'Agfa',
#  'AgfaPhoto',
#  'Aiptek',
#  'Alpine',
#  'Apex Digital',
#  'Apple',
#  'Argus',
#  "As customer's request",
#  'Asus',
#  'Audiovox',
#  'Axess',
#  'BVI',
#  'Bang & Olufsen',
#  'Bell & Howell',
#  'BenQ',
#  'Benq',
#  'BetterLight',
#  "Big Mike's",
#  'BlackMagic Design',
#  'BlackMagicDesign',
#  'Blackmagic',
#  'Blackmagic Design',
#  'Blackmagicdesign',
#  'Bonzart',
#  'Brinno',
#  'Bushnell',
#  'ButterflyPhoto',
#  'CANU9',
#  'CHOBi',
#  'CLASS',
#  'COBRA',
#  'COMBOTEK',
#  'COMPUTER PARTNER',
#  'CXIN',
#  'Caden',
#  'Cambo',
#  'Camera',
#  'Canon',
#  'Canon Cameras, US',
#  'Canon power shot sx130',
#  'Canon/Japan',
#  'CarBose',
#  'Carbose',
#  'Casio',
#  'Celltime Inc.',
#  'Chinon',
#  'Circuit Street',
#  'Cobra',
#  'Cobra Digital',
#  'Coby',
#  'Coleman',
#  'Concord',
#  'Contax',
#  'Contour',
#  'Contour, Inc',
#  'Crayola',
#  'D-LINK',
#  'DGX',
#  'DJI',
#  'DNT',
#  'DV',
#  'DXG',
#  'DXG TECHNOLOGY',
#  'DigiFlip',
#  'Digital',
#  'Digital Blue',
#  'Digital Blue Corporation',
#  'Digital Camera For Dummies',
#  'Digital Concepts',
#  'Digital Labs',
#  'Digital Prism',
#  'Discovery Kids',
#  'Disney',
#  'Drift',
#  'Dynex',
#  'EOS',
#  'Easypix',
#  'Element',
#  'Elite Screens',
#  'Emerson',
#  'Emprex',
#  'Epson',
#  'Evolt',
#  'FUJI9',
#  'FVANOR',
#  'Fantasea',
#  'Favi Entertainment',
#  'Fisher Price',
#  'Flip Video',
#  'Focus',
#  'For Nikon P60',
#  'For Nikon S2',
#  'Fotoman',
#  'Fotopix',
#  'Fuji',
#  'Fuji Photo Film',
#  'FujiFilm',
#  'Fujifilm',
#  'Fujifilm finepix telephoto digitalcamera',
#  "G.T or as per customer's requirement",
#  'GE',
#  'GE GENERAL ELECTRIC',
#  'GE General Imaging',
#  'GID',
#  'GLOBAL POINT',
#  'GOPRO',
#  'GPX',
#  'Garmin',
#  'Garmin Parts',
#  'Gateway',
#  'General Electric',
#  'General Imaging',
#  'General Imaging GE',
#  'Genius',
#  'Gizmon',
#  'Global Point',
#  'GoPro',
#  'God condition',
#  'Gopro',
#  'HASSELBLAD',
#  'HP',
#  'Hasselblad',
#  'Hello Kitty',
#  'Hewlett Packard',
#  'Hisense',
#  'Hitachi',
#  'Horseman',
#  'Humminbird',
#  'IMAGING APPARATUS',
#  'INTOVA',
#  'ION',
#  'Innovage',
#  'Insignia',
#  'Insigniaâ\x84¢',
#  'Intel',
#  'Intova',
#  'Islands Earth',
#  'JLB',
#  'JVC',
#  'Jakks Pacific',
#  'Jazz',
#  'Jazz Dv150',
#  'Joco',
#  'Jumbl',
#  'Jvc',
#  'KBGear Interactive',
#  'KEEDOX',
#  'KTV',
#  'Keedox',
#  'Kenko',
#  'Kobian Group',
#  'Kodak',
#  'Kodak Optical Zoom: 8x',
#  'Kodak, Samsung, Vivitar, Canon , Olympus',
#  'Kogan',
#  'Konica Minolta',
#  'Kowa',
#  'Kyocera',
#  'LG',
#  'LG Electronics',
#  'LITTLE SHOTS',
#  'LTL Acorn',
#  'Largan Group',
#  'Leica',
#  'Leica Camera',
#  'Lexar Media',
#  'Lifeworks',
#  'Limited Too',
#  'Little Acorn',
#  'Logitech',
#  'Lomo Cameras',
#  'Lowepro',
#  'Lowrance',
#  'Lytro',
#  'MAGELLAN',
#  'MEGA PRO',
#  'MERCURY',
#  'MUSTEK',
#  'Magnavox',
#  'Mamiya',
#  'Mamiya AFD ii',
#  'Mattel',
#  'Megapix',
#  'Mercury Electronics',
#  'Micro Solution of Japan',
#  'Midland',
#  'Mikona',
#  'Minolta',
#  'Minox',
#  'Mitsuba',
#  'Mitsubishi',
#  'Mobius',
#  'Monoprice',
#  'Motorola',
#  'MotorolaThis is a nice, Motorola',
#  'Moultrie Feeders',
#  'Mustek',
#  'NEC',
#  'NEOpine',
#  'NIK',
#  'NIKO9',
#  'Naxa',
#  'New',
#  'Next',
#  'Nikon',
#  'Nikon\nType:\nDigital SLR',
#  'Nikon Megapixels: 12.1 MP',
#  'NikonEu',
#  'Nokia',
#  'OEM',
#  'OEM (digital bag)',
#  'OLYMPU',
#  'Olivia',
#  'Olympus',
#  'Opteka',
#  'Optimus',
#  'Optiz',
#  'Oregon Scientific',
#  'PENTAX Corporation',
#  'PENX9',
#  'PYLE-SPORT',
#  'Palm Clix',
#  'Panasonic',
#  'Panasonic / Lumix',
#  'Panasonic Limix',
#  'Panasonic/Lumix',
#  'Pentax',
#  'Pentax-Ricoh',
#  'Phase One',
#  'Philips',
#  'Phoenix',
#  'Pioneer',
#  'Pioneer Research',
#  'Polaroid',
#  'Praktica',
#  'Proscan',
#  'Protax',
#  'Protron',
#  'Pure Digital',
#  'QFX',
#  'QuantumFx',
#  'RCA',
#  'Radio Shack',
#  'Revo',
#  'Ricoh',
#  'Ricoh Cameras USA',
#  'Rollei',
#  'SAKAR',
#  'SEARS',
#  'SHOOT',
#  'SIGMA',
#  'SJ4000',
#  'SSE',
#  'SVP',
#  'Sakar',
#  'Samsung',
#  'Samsung Pleomax - Zirex',
#  'Sanyo',
#  'Sceptre',
#  'SeaLife',
#  'SeaLife ReefMaster',
#  'Seiki Digital Inc.',
#  'Sharp',
#  'Sharper Image',
#  'Shimano',
#  'SiPix',
#  'Sigma',
#  'Skyguide',
#  'Skyworth',
#  'Slick',
#  'Sony',
#  'Spectra Merchandising International',
#  'Speedo',
#  'Spongebob',
#  'Star System',
#  'Superheadz',
#  'Supersonic',
#  'Sylvania',
#  'Symphonic',
#  'TCL',
#  'THE SHARPER IMAGE',
#  'Tamron',
#  'Tandberg',
#  'Telecom',
#  'Telesin',
#  'Telesin or custom',
#  'Tenvis',
#  'The Sharper Image',
#  'Toi Kamera',
#  'Topixo',
#  'Toshiba',
#  'TrendNet',
#  'Tvc',
#  'Unbranded',
#  'Unbranded/Generic',
#  'Unknown',
#  'VIBE',
#  'VIDPRO',
#  'VTech',
#  'Venturer',
#  'Vibe',
#  'Vista Quest',
#  'VistaQuest',
#  'VistaQuestÂ',
#  'Vistaquest',
#  'Vivitar',
#  'Vivitar & Samsung',
#  'Vivitar, Kodak, Sanyo, Nikon',
#  'Vizio',
#  'Vizio, Inc.',
#  'Vtech',
#  'VuPoint',
#  'VuPoint Solutions',
#  'Wespro',
#  'Westinghouse',
#  'Winait',
#  'Wingscapes',
#  'Wusthof',
#  "XT or Customer's Brand",
#  'Ximea',
#  'YAXIUMEI or OEM',
#  'Yashica',
#  'YourDeal',
#  'Yourdeal',
#  'ZEEMO',
#  'ZMODO',
#  'Zeiss',
#  'Zenith',
#  'access HD',
#  "anxu or Customer's brand",
#  'aquapix',
#  'comers',
#  'cyber-cam',
#  'digital camera',
#  'digital concepts',
#  'easypix',
#  'ebasket',
#  'for Canon G1X Mark II',
#  'for Canon SX510',
#  'for Panasonic GM1',
#  'fotopix',
#  'godspeed',
#  'iClick',
#  'i_p.mium',
#  'intova',
#  'nabi',
#  'new',
#  'precision',
#  'sakar',
#  'sciwin',
#  'unbrand',
#  'unbranded 252 generic',
#  'unknown'}

# %%
# models = set([])
for i in products['www.alibaba.com'].values():
    if 'model' in i:
        print (i['model'])
        if type(i['model']) == list:
            for m in i['model']:
                models.add(m)
        else:
            for m in i['model'].split(' '):
                models.add(m)
# Out:
# HD-SD6A220-HS HD-SD6A230-HS
# IPC-HFW3110P IPC-HFW3110N
# DH-SD6AW220-HN DH-SD6AW230-HN
# F719-AHD1001 F719-AHD1301
# IPC-HDBW5502 IPC-HDB5502 IPC-HDBW5502-DI IPC-HDB5502-DI
# For NEX5(18-55mm)(universal waterproof camera case)
# AX-S200VDA-IP
# BPSW75HD
# DH-IPC-HDB3200CP DH-IPC-HDB3200CN
# VT-9023B VT-9123B VT-9213HB VT-9313B VT-9413B VT-9513B
# GS-1020ZH GS-1021ZH GS-1022ZH
# DH-IPC-HDB4300C-(A)
# DH-IPC-HFW3300CP DH-IPC-HFW3300CN
# MY-130W-764
# SD6A220-HN SD6A230-HN SD6AS220-HN
# DH-SD6C230S-HN
# I204-480
# SD6A220-HN SD6A230-HN SD6AS220-HN
# DH-SD6AW220-HN DH-SD6AW230-HN
# BTF75V-SN7
# For NEX5N(18-55mm)(universal waterproof camera case)
# BP20S-1H
# DH-SD59220S-HN
# HD-SD6582-HS HD-SD6582A-HS
# BV40AU-H122X
# SD6A220-HN SD6A230-HN SD6AS220-HN
# C901-061Z
# JD-WP1177D JD-WP1177H JD-WP1177J JD-WP1177K JD-WP1177L JD-WP1177N
# AS-8904
# GK-G130P-151(All metal construction)
# IPC-HDBW5502 IPC-HDB5502 IPC-HDBW5502-DI IPC-HDB5502-DI
# IPC-HDBW5502 IPC-HDB5502 IPC-HDBW5502-DI IPC-HDB5502-DI
# IPC-HFW5502C
# DH-SD6C230S-HN
# VT-8035Z VT-8235Z VT-8435Z VT-8135Z VT-8835Z VT-8335Z
# AX-S200DQ-IP
# C901-056Z
# IPC-HDBW3200P IPC-HDBW3202P IPC-HDBW3200N IPC-HDBW3202N
# SAV-CM1011
# DH-SD59220S-HN
# YC-850AHBB85
# DH-SD59220S-HN
# DH-IPC-HFW5200C DH-IPC-HFW5202C
# CTA01H4
# DH-SD59220S-HN
# DH-SD6AW220-HN DH-SD6AW230-HN
# IPC-HDBW5502 IPC-HDB5502 IPC-HDBW5502-DI IPC-HDB5502-DI
# DH-SD59220S-HN
# CW-N7989
# DH-IPC-HFW2100P DH-IPC-HFW2100N
# DH-SD6C230S-HN
# SY-IP4021HW SY-IP4022TW SY-IP4023TW
# DH-SD6AW220-HN DH-SD6AW230-HN
# DH-SD6AW220-HN DH-SD6AW230-HN
# IPC-HDBW3200P IPC-HDBW3202P IPC-HDBW3200N IPC-HDBW3202N
# DH-SD59220S-HN
# SD6A220-HN SD6A230-HN SD6AS220-HN
# DH-IPC-HDBW3300P DH-IPC-HDBW3300N
# GS-HDR130
# IPC-HFW5502C
# DH-IPC-HDB4300C-(A)
# DH-IPC-HDB3300P DH-IPC-HDB3300N
# DH-SD6C230S-HN
# SD6A220-HN SD6A230-HN SD6AS220-HN
# IPC-HFW5502C
# DH-SD6AW220-HN DH-SD6AW230-HN
# B-250W-5V B-250W-12V B-250W-15V B-250W-24V B-250W-36V
# IPC-HFW5502C
# IPC-HFW5502C
# IP-545t-5010B-A IP-545t-5013B-C IP-545t-5020B-E IP-545t-5020D-E
# DH-IPC-HFW2100P DH-IPC-HFW2100N
# TWD-IAV004-540E
# SD6A220-HN SD6A230-HN SD6AS220-HN
# SD6A220-HN SD6A230-HN SD6AS220-HN
# DH-SD6AW220-HN DH-SD6AW230-HN
# TWD-IAV002-700E
# DH-SD6583A-HN
# SD6A220-HN SD6A230-HN SD6AS220-HN
# IPC-HDBW3200P IPC-HDBW3202P IPC-HDBW3200N IPC-HDBW3202N
# For GF3 (14-42mm) (waterproof camera case)
# DH-IPC-HFW3300CP DH-IPC-HFW3300CN
# DH-SD6582-HS DH-SD6582A-HS
# ASB-P288GM-V1
# SD6A220-HN SD6A230-HN SD6AS220-HN
# DH-SD59220S-HN
# DH-SD6980-HN DH-SD6981-HN
# DH-IPC-HFW2100P DH-IPC-HFW2100N
# Specifications Chief Characteristic Board specification
# DH-IPC-HDBW3300P DH-IPC-HDBW3300N
# DH-IPC-HFW2100P DH-IPC-HFW2100N
# WIP130-WT40
# HD-SD6A220-HS HD-SD6A230-HS
# DH-IPC-HD2100P DH-IPC-HD2100N
# EW-73B
# DH-SD59220S-HN
# DH-IPC-HFW3300P DH-IPC-HFW3300N
# GK-3011P
# DH-IPC-HDBW3300P DH-IPC-HDBW3300N
# SY-IPL5021TMW SY-IPL5022TMW SY-IPL5023TMW
# 10D
# DH-IPC-HFW3300P DH-IPC-HFW3300N
# DH-IPC-HDB3300P DH-IPC-HDB3300N
# DH-IPC-HFW2100P DH-IPC-HFW2100N
# DF-3003RN DF-3003R
# IC-LBMW30-ESR IC-LBMW30-ESS IC-LBMW30-ESA IC-LBMW30-ESQ IC-LBMW30-ESK IC-LBMW30-ESF
# SD6C23C-H SD6C23E-H SD6C36E-H SD6C70-H
# IPC-HDBW8301
# UTK-MS30770
# DH-IPC-HFW2100P DH-IPC-HFW2100N
# YC-W930AHZ37 YC-W931AHZ37 YC-W932AHZ37
# SD6A220-HN SD6A230-HN SD6AS220-HN
# IPC-HDBW5502 IPC-HDB5502 IPC-HDBW5502-DI IPC-HDB5502-DI
# PST-IRC007CL
# DH-SD6AW220-HN DH-SD6AW230-HN
# SD6A220-HN SD6A230-HN SD6AS220-HN
# H-IP6131B
# SK-N1207
# SD6A220-HN SD6A230-HN SD6AS220-HN
# IPC-HDBW5502 IPC-HDB5502 IPC-HDBW5502-DI IPC-HDB5502-DI
# AHDDM24G-10M
# IC-LDMW30-ASR IC-LDMW30-ASS IC-LDMW30-ASQ IC-LDMW30-AHM IC-LDMW30-ASK IC-LDMW30-ASF
# ZAF103-S ZAF1031-S ZAF1031-S-LA ZAF1032-S ZAF1032-S-LA ZAF1032-S-LA2
# SD6A220-HN SD6A230-HN SD6AS220-HN
# SD6A220-HN SD6A230-HN SD6AS220-HN

# %%
models
# Out:
# {'S90',
#  'R967',
#  'A2000 IS',
#  'X400',
#  'PST-IPC161',
#  '0007410100359',
#  'D80',
#  'Dsc S2000',
#  'VT027-RH-BUNDLE',
#  'Dmc-f5',
#  'Nikon D',
#  'Nikon S1',
#  'F750EXR',
#  '4010',
#  'LUMIX DMC-TS1',
#  'PDC 640',
#  'Powershot A 85',
#  'PowerShot S90',
#  '80-122801',
#  'power shot sd 1400 is digital elph',
#  '550 D',
#  'ILCE-6000L/S',
#  'GR-NW2818BZ',
#  'Powershot SX20 IS',
#  'EX-Z16',
#  'SD940 IS',
#  'SS-612E3-1',
#  'E-620',
#  'AW1',
#  '80 IS',
#  'TV-LED1611',
#  '0004177196926',
#  'SY-IPL5022TMW',
#  'L26',
#  'EOS Digital Rebel XTi / 400D',
#  'PHOTO EASY',
#  'DSC-TX100V',
#  'Finepix S3300',
#  'Tough 1010 / Âµ (mju) 1010',
#  'GR Digital',
#  '2V7WP-BL',
#  'A490',
#  'DMC-FX90',
#  '8676B001',
#  'COOLPIX L810',
#  'NEXC3A',
#  'EX-S500',
#  'YC-W930AHZ37 YC-W931AHZ37 YC-W932AHZ37',
#  'SX700 HS',
#  'SD980 IS',
#  'PL22',
#  'W10',
#  'DSC-W50',
#  'DSC-HX100',
#  'PEN E-PM2',
#  'DV-1100-BL',
#  'X-Pro1',
#  'X426',
#  'Silver Edition',
#  '3579',
#  'SeaLife ReefMaster DC310',
#  't250',
#  'DH-IPC-HFW3200SP',
#  'C-3030 Zoom',
#  'DSC-S730',
#  'PowerShot G9',
#  'IC-LBMW40-DSF',
#  'a7',
#  'Sx260 HS',
#  'DSC-M1',
#  '2000',
#  'KDL-55HX800',
#  'D700',
#  'M531',
#  '5169B003AA',
#  'Item No. LT-1S90SN2AHDY0E',
#  'F470',
#  'Rebel XSi / 450D',
#  'Nex-3N',
#  '57H83',
#  'GR-NW0718',
#  'CL-F16ED/W',
#  '5.0MP HD1080P Wifi Sport Action Video Camera',
#  '0004177124757',
#  'For P7000 (Waterproof Camera Case)',
#  'V',
#  'Slt-A58k',
#  'JD-WP1177K',
#  'WIDP80-LB10',
#  'ZD',
#  '318',
#  'Digital ELPH SD960 IS / Digital IXUS 110 IS',
#  'DX4900',
#  'LCD 3',
#  'A400',
#  'Canon EOS',
#  'For NEX5N(18-55mm)(universal waterproof camera case)',
#  'Coolpix S6500',
#  '1 V1',
#  'Rebel XT / 350D',
#  'Pentax K-500',
#  'LS465',
#  'S40',
#  'T328',
#  'VG-140',
#  'VT-9012HB',
#  'T200',
#  '50HM56',
#  'Tough 8000',
#  'DHT235C',
#  'T100HD-W',
#  'VT-9022HB VT-9122HB VT-9322HB VT-9722HB VT-9122HB VT-9422HB',
#  'case)',
#  'CAMEDIAD - 580',
#  'SD6AS220-HN',
#  'IC-LBMW40-FSF',
#  'DSC-W300',
#  'NX2000',
#  'Princess Flowers',
#  'WIDS72V-LB10',
#  'DSC-L1',
#  'C183',
#  'Photosmart A430',
#  'SS-227E3-1',
#  'BE-SDO70',
#  'X20',
#  'Rebel 300D',
#  '4800 Zoom',
#  'SLT-A37K',
#  'DSC-W200',
#  'IC-12',
#  'X505BV-FMQR',
#  'THETA',
#  'DSC-WX300',
#  'T2i / EOS 550D',
#  'Express&reg; Deer',
#  'ELPH 110 HS',
#  'BCX-CJ36SF',
#  'D-705',
#  'EOS REBEL T2i',
#  'C901-033Z',
#  'DMC-FZ1',
#  'V1233',
#  'S2980',
#  'S 6600',
#  'IC-ILBMW40-AT3',
#  'E-410',
#  'FE-4020',
#  'UN60H6300AF',
#  'd50',
#  'WG-3 GPS',
#  'Lumix Dmc-Tz10',
#  '0001820813145',
#  'DSC-H3',
#  'sy-1260',
#  'GS-1022ZH',
#  'IXY 32S',
#  'ABC-C-S73835A',
#  'C1033',
#  'DH-IPC-HDB4300C-(A)',
#  'VT-9023B VT-9123B VT-9213HB VT-9313B VT-9413B VT-9513B',
#  'BE-SDO70 BE-SDO70Z BE-SDO60C',
#  'JX350',
#  'GS-HDR140 GS-HD141',
#  'Panasonic DMC-G6',
#  '0001820826196',
#  'PSSX170IS',
#  'M Digital',
#  'Eos 1200d kit (ef S18-55 is ii)',
#  '4000',
#  'DMC-FZ50',
#  '0004177194619',
#  'SD 1000',
#  'F300EXR',
#  'ZAT670-S',
#  'CL-866A8D/W',
#  'NX30',
#  'X600',
#  'DSC-TX7',
#  'C-3020 Zoom',
#  'T5',
#  'A1230',
#  '730',
#  '227590',
#  'C360',
#  'Stylus vh-520',
#  'SH-1',
#  'sx40hs',
#  '0002724274568',
#  'Vg-165',
#  'NE-HDS155FS',
#  'EOS REBEL T5i',
#  'DSC-H20',
#  'SZ-11',
#  '201',
#  'AI-A768PFZ37',
#  'DC-C517-VP',
#  'Tough 8010',
#  'V104150SU000',
#  '227670',
#  'WI-1819D',
#  'Network',
#  'DMC-FH6/DMC-FS40',
#  'IC-LBW20-ECQ',
#  'C-3040ZOOM',
#  'IPC-HDB3200CJL',
#  'A4',
#  'E500I-B1',
#  'JX680',
#  'NEX7KB',
#  'S5100',
#  'UN46F7100',
#  'V5022GRP',
#  '13073',
#  'Tough 6000 / Âµ (mju) Tough 6000',
#  'DIGITAL CAMERA',
#  '29PFL4508',
#  'WIDS72V-LB10 WIDS72A-LB10 WIDS70-LB10 WIDS65-LB10 WIDP80-LB10 WIDP8A-LB10 WIDP7A-LB10',
#  '0001380310468',
#  'DF-3003R',
#  'AW-E300',
#  'KODAK NC-2000E-C',
#  'K 30 Body Only',
#  '40D',
#  'S6000',
#  'LKPH0024',
#  'MVC-FD90',
#  'Dsc-Qx10 Cyber Shot',
#  'VG-160 / D-745',
#  'SAV-CM1011',
#  'ST201',
#  'S7000',
#  '226085',
#  'IP-583t-U-5020D-E',
#  '0001380311925',
#  'Dmc-Fz70k',
#  'C182',
#  'UN22F5000',
#  'COOLPIX l820',
#  'Zi10',
#  'N',
#  'Wushtof Silverpoint II',
#  '0004177147330',
#  'BV40DB-IP13H',
#  'DCA1670',
#  'I8',
#  'Sport',
#  'DSLR-A500',
#  'SD1100',
#  'Cybershot Dsc-W510',
#  'MKJ-IPC06',
#  'XO22',
#  'DH-IPC-HFW2100P',
#  'Digital Rebel XTi / 400D',
#  '0001820813019',
#  'XTC400',
#  'B-250W-5V B-250W-12V B-250W-15V B-250W-24V B-250W-36V',
#  'Hc-W850',
#  'Cybershot',
#  'X800',
#  'AZ 501',
#  'L21',
#  'X1400',
#  'SLT-A77',
#  'DSC-QX100',
#  'P44417P',
#  'VPC-E1500TP',
#  'SD1000',
#  'IPC-W603',
#  'ZAT670-S-IP',
#  'Digital ELPH SD40 / Digital IXUS i7 Zoom',
#  '0002724279301',
#  '1D',
#  'C-211 Zoom',
#  'Es90',
#  'DMCGF3XK',
#  'TSAS40-811',
#  '(waterproof',
#  'VT-9422HB',
#  'DH-IPC-HDB3300N',
#  'ELPH 520 HS / IXUS 500 HS',
#  '0007976749411',
#  'D70',
#  'EF-M',
#  'Half D',
#  'Î±290',
#  'PowerShot SX400 IS',
#  'TWD-I204',
#  'S5',
#  'Aquos LC45GX6U',
#  'Pro-436 PU',
#  'Z340',
#  'none',
#  'Eos 1200d (Body)',
#  '227735',
#  'CT-DR9323A',
#  'DW-7B',
#  'KDV-3089',
#  'TWD-I108RD',
#  'CT-DR7422H',
#  'DH-IPC-HDB3110P',
#  'C315',
#  'Hc-V250',
#  'DMC-ZS25 / DMC-TZ35',
#  'DF-7554RN',
#  'X-M1',
#  'UN40EH5300',
#  'TV-LED1912D',
#  'Nex-5',
#  '32V550T',
#  'IPH16DB2-IR2',
#  'FUJIFILMS9150',
#  '50L2400U',
#  'VT-9513B',
#  'A4000 is',
#  '228825',
#  '635',
#  'DV',
#  'C25',
#  'C5WP',
#  'X50',
#  'A530',
#  'A850',
#  'DSC-H50',
#  'MVC-CD1000',
#  '0001820826235',
#  'DH-IPC-KW12(W)',
#  'ZAT630-S-IP',
#  'Z5120',
#  'EX-ZS26RD',
#  'HS25EXR',
#  'APM-JP8015-WS',
#  'Samsung NX1000',
#  'L20',
#  'C901-064Z',
#  'Q',
#  'E90',
#  'K100D',
#  'Universal Waterproof Camera Case',
#  'DMC-ZS30 / DMC-TZ40',
#  'DMC-TZ40',
#  'Nex-5tl',
#  'IPC-HDB5502',
#  'EC-AHC1313C',
#  'Palm Cam Super Disk',
#  'SP-500 UZ',
#  'Olympus',
#  'NIKON 1J2',
#  'GR Digital II',
#  'S5000 Zoom',
#  'DSC-H200',
#  'DSC-W620',
#  'CLIPSTER',
#  'A350',
#  'TC-32LX50',
#  'DH-IPC-HDW3200SN',
#  'A720 IS',
#  'RS1000',
#  'G6',
#  'V10',
#  'JX665',
#  'BY-IPVPWD1S',
#  'Fine Pix digital camera 2650',
#  'Z1285',
#  'BF20W-S70A',
#  'HDR-Pj230e',
#  'EOS Rebel XS',
#  'ST68',
#  'DMC-LC1',
#  'POWERSHOT SX270HS',
#  'IC-500',
#  'Pen Lite e-pl3',
#  'CX-0001-51',
#  'D2Xs',
#  'ILCE6000/B',
#  'PENTAX Q7 Body/Black',
#  'DS6628',
#  'A1300',
#  'C-5060 Wide Zoom',
#  'XP200',
#  'MLD-CB020',
#  'SP-500UZ',
#  'TWD-I402L',
#  'DMC-SZ8',
#  'A1100 IS',
#  'AI-I130IBE',
#  'EDC210',
#  'DS126311',
#  '435',
#  'A2300',
#  'C763',
#  'Hit',
#  'AW120',
#  'L30',
#  'Digital ELPH SD630 / Digital IXUS 65',
#  'HDR-As30v Full HD Action',
#  'VT-1516VH',
#  'S6400',
#  '58l8400',
#  'NX210',
#  'A735',
#  'Nikon J3',
#  'EOS 30D',
#  'DH-IPC-HFW5200C DH-IPC-HFW5202C',
#  'Parameters',
#  'M40',
#  'R607 Harajuku Lovers Digital Camera by Gwen Stefani',
#  'Z981',
#  'M2',
#  '500',
#  'EOS-1D X',
#  'IP063-5.0MP',
#  'IC-LD20-ASK',
#  'VT-9514HB',
#  'DH-IPC-HDB4100CN',
#  '995',
#  'Sl280',
#  'FE-5020',
#  'SX1 IS',
#  'Dmc-fh7',
#  'SX500 IS',
#  'S400 ELPH',
#  'A800',
#  'EX-S8',
#  'Z33WP',
#  'C5WP-GN',
#  'DMC-LC70',
#  'PC1468',
#  '0004177824840',
#  'C-5050 Zoom',
#  'NX20',
#  'GXR MOUNT A12',
#  'E320i-B2',
#  'DMC-FP3',
#  'Z2',
#  'E221-A1',
#  'C618',
#  '0827D562',
#  '9341B001',
#  'DH-IPC-HFW4200SP DH-IPC-HFW4200SN',
#  'L50',
#  'DG-MN11-D38',
#  'F72EXR',
#  'TSAS40-3089',
#  'CD83',
#  'Gr',
#  'DSCRX100/B',
#  'W524',
#  'Optio Z10',
#  'DMC-G6KK',
#  'NX200',
#  'P6000',
#  'AHDDM24G-10M',
#  '0004177135076',
#  'DSC-TX9',
#  'DMC-TS2/DMC-FT2',
#  'NS-LTDVD19-09',
#  'Light Field',
#  'DC-M42',
#  '618',
#  'Maxxum 7D',
#  'ELPH 320 HS / IXUS 240 HS',
#  '0005033217952',
#  'DC-5502A',
#  'DH-IPC-HF8301EN',
#  'VT-8435Z',
#  '812',
#  'VPC-S1085P',
#  'conditioner',
#  'VQ 1024',
#  'R-D1s',
#  'HARINEZUMI',
#  '5745BE4E',
#  'MVC-FD88',
#  'GS-W7001C',
#  'Cybershot DCS-600',
#  'EX-G1',
#  'SX100 IS',
#  'DSCRX100M2/B',
#  'P-704',
#  'Cyber-shot DSC-W690',
#  'T833',
#  'B-250W-15V',
#  'DH-IPC-HFW5200CP',
#  'Hz15',
#  '0088517003320',
#  'Digital ELPH SD400 / Digital IXUS 50',
#  'D3000 10.2 PM SLR CAMERA',
#  '32LN630R',
#  'Wg iii',
#  'IC-LD20-ASF',
#  'Mini II Elite',
#  '760',
#  'DMC-FS15',
#  'TWD-I608-600',
#  'UN46F7500AF',
#  '55EA9800',
#  'SD800 IS',
#  'PC1209',
#  'KT1210/CLR',
#  'A470',
#  'EOS 1D markIII',
#  '0002724227330',
#  '0001380310121',
#  'AS-CH10331HZY',
#  'DMC-FX07',
#  'DH-IPC-HFW3300P DH-IPC-HFW3300N',
#  'DMC-ZS35',
#  'Coolpix S31',
#  'SD6A220-HN SD6A230-HN SD6AS220-HN',
#  'X137',
#  '0004177102030',
#  'power shot A460',
#  'DMC-ZS10/DMC-TZ20',
#  'DMC-FS3',
#  'C12WP-BL',
#  'CW-N7989',
#  'EX-S5',
#  'S6500',
#  'A230',
#  's',
#  'Stellar Silver Walnut Wood grip',
#  'C-55 Zoom',
#  'MPEG4',
#  'Eos 5d Mark iii kit (ef 24-105 mm F/4l is Usm)',
#  'P500',
#  'DF-IP6136LN',
#  'CL-F60NHII/CW',
#  'KDL-46EX640',
#  'DSLR-A550',
#  'M550',
#  '25482',
#  'VT-9023B VT-9323B VT-9413HB VT-9513B VT-9613B VT-9813B',
#  'KS-536MW',
#  '0001380309090',
#  'CS630',
#  'ERA-0636HD',
#  'IC-LDMW30-ASS',
#  'Hero 4 silver',
#  'D7000',
#  'EOS Digital Rebel XT',
#  'IC-LDMW30-DSR IC-LDMW30-DSS IC-LDMW30-DSQ IC-LDMW30-DHM IC-LDMW30-DSK IC-LDMW30-DSF',
#  'IS085',
#  '850 SW',
#  'FUN! 320',
#  'CT-DR7382H',
#  'DMC-FH25',
#  'REAL 3D W1',
#  'XP20',
#  'DMC-FS8',
#  'TOP-S1000',
#  'PoGo',
#  'AX300',
#  'DC6550',
#  '600 Digital',
#  'DH-SD6582-HS DH-SD6582A-HS',
#  'DMC-FS25',
#  'D-490 Zoom',
#  '0088517001605',
#  'Easy Share',
#  'DSCTX55',
#  'WP7 BLACK',
#  'L11',
#  'L23',
#  'Eos 1200d',
#  'Tough 550WP / Âµ (mju) 550 WP',
#  'PowerShot SX20 IS',
#  'D300',
#  'X-560WP',
#  'Hero3',
#  'CT-DR7383A',
#  'DV-8',
#  '115 IS',
#  '5D Mark II',
#  'EK GC200',
#  'DMC-TZ1',
#  '5400',
#  'SP-100EE',
#  'F900EXR',
#  'A436',
#  '0001600013158',
#  'DSC-H9',
#  '0007410101449',
#  'S110',
#  'L610',
#  'R607xi',
#  'IPC-HDBW5502',
#  'DSC-W210',
#  'G11',
#  'M577',
#  'D4',
#  'E500i-A1',
#  'DSC-TX200V',
#  'Ixus 135',
#  'ZS5',
#  '5TL',
#  'DSC-P32',
#  'VT-9021HB',
#  'Canon T3i',
#  'TOP-S1000 WJSMS',
#  'L1',
#  'A650 IS',
#  '5386',
#  '700d',
#  'Canon EOS\nA CCD sensor will provide a sharper more precise image, but is generally more power consuming. CMOS sensors are generally more energy efficient and are creating better and better images as technology develops.',
#  'V527 DIAMOND',
#  'EasyShare C182',
#  'G10',
#  'DSLR-A350',
#  'E1680',
#  'RY-8003B',
#  'SY-IPL5021TMW SY-IPL5022TMW SY-IPL5023TMW',
#  'FinePix S4830',
#  'C12WP',
#  'L700',
#  'PST-DHB6R-XS',
#  'PL20',
#  'SZ-16 iHS',
#  '3M',
#  'C643',
#  'D2HS',
#  '16486',
#  'IPC-HDBW3202P',
#  'S02',
#  'Finepix Jv100',
#  'VT-8049Z',
#  'SX130 IS',
#  '1400',
#  'DMC-TS1/DMC-FT1',
#  'DMCFP3A',
#  'LCD',
#  'NEX-5K',
#  'VX5',
#  'F131',
#  '0004177800958',
#  'DMCGX7SBODY',
#  'CD50',
#  'V2',
#  'EX-N10',
#  '5700',
#  'E70',
#  'VT8649Z',
#  'G16',
#  'ZAT670-S-HD ZAT670-S-IP ZAT670-S',
#  'Mobius',
#  'Pro',
#  'VGA Carabiner',
#  'Hero 3+ Plus Black Edition',
#  '0001820826142',
#  '0002724274920',
#  'FE-25',
#  'KDL-40BX421',
#  'SP-550 UZ',
#  'Nikon D7100',
#  'W1024-P',
#  'Sj4kydblk',
#  'NX100',
#  'DF-7548RN',
#  'J1',
#  '16000480',
#  'WIDP8A-LB10',
#  'W800',
#  'T2i',
#  'FE-230',
#  'Xacti VPC-HD2',
#  'A65',
#  'DSC-H7',
#  'Horseman LX/LD',
#  'SD870 IS',
#  '16008432',
#  'Nikon Coolpix A',
#  '400D',
#  'DSC-P31',
#  'DMC-FZ47 / DMC-FZ48',
#  'IPC732V2',
#  '215 Zoom Millennium',
#  'M60',
#  'Dsc W210',
#  'DSC Digital SpyCam',
#  'DMCZS25S',
#  'Rebel T5',
#  'DXG-301V',
#  'K-5 II s',
#  'Z100 fd',
#  'Z950',
#  'powershot elph 500 hs',
#  'ILCE5000L/B',
#  'Rebel T4i',
#  'PowerShot Digital ELPH SD950 IS /',
#  'DMC-FX30',
#  '0001820826164',
#  '150',
#  'SD1 Merrill',
#  '0004470101647',
#  '16301',
#  'YC-W930AHZ37',
#  'ST100',
#  '989-000101',
#  'IC-LDW20-AHA',
#  'EOS 600D',
#  'EX-Z700',
#  '013803237160',
#  'Sunglasses',
#  '0001380310941',
#  'WP16-Y',
#  'C3WP-BL',
#  'BL1050',
#  'SAV-CM811V',
#  'DSC-T900',
#  'DF-6036DS',
#  'G5',
#  'X1200',
#  'DMC-FX7',
#  'Powershot S110',
#  'd800',
#  'Wg-4',
#  'Dsc W510',
#  'DSC-P30',
#  'DSC - W560',
#  'M8',
#  'HD1Z',
#  'Epson RD-1',
#  'hero 2',
#  'SX110 IS',
#  'D-100 / CAMEDIA C-1',
#  'DSC-S780',
#  'Digital ELPH SD880 IS / Digital IXUS 870 IS',
#  'KST-I521-CV1301',
#  'St30',
#  'F40fd',
#  'GK-3011P',
#  'P44417W',
#  'E-P2',
#  'CoolPix L4',
#  'ATC2K',
#  'DSC-WX7',
#  'C3',
#  'YC-850AHBB89D',
#  'Zi6',
#  'DSC-W150',
#  'Sx510 HS',
#  '94009',
#  'Nikon D\nHigher-end cameras may allow you to separate the camera body from the lens, allowing you to interchange lenses for different types of photography.',
#  'BE-SDO60C',
#  '0088517007087',
#  'COOLPIX 5550',
#  'R707',
#  'IC-LBMW30-ESK',
#  'NEX-5',
#  'SP-820UZ',
#  'P44417A',
#  'TL220',
#  'EX-Z80',
#  'UN48H6350',
#  'IC-LD20-ASR IC-LD20-ASS IC-LD20-ASQ IC-LD20-AHM IC-LD20-ASK IC-LD20-ASF',
#  'IPC-1040LXV',
#  'SAV-CM512V',
#  'DW-6B',
#  'video',
#  'Fabulous Fuzzy',
#  'NEX-6/B',
#  'D3s',
#  '10704',
#  'DMCG6KK',
#  '1540',
#  'VT-9112HB',
#  'KD-0702',
#  'CyberShot',
#  'T300 / T305',
#  'CD82',
#  '1100D',
#  'Sl 62 Dual LCD',
#  'DH-HAC-HDW2200SP',
#  'EOS 40D',
#  '0001380312682',
#  'Mini DIGITAL',
#  'DSC-P72',
#  'Stellar Silver Carbon Fiber grip',
#  'JPT3815W',
#  'AX250',
#  'DSC-W7',
#  'LE32HDF3010',
#  '220 HS',
#  'Digimax 360',
#  'L200',
#  'NE-HDS158VS',
#  'IC-LBW20-ECK',
#  'Duo 2V7WP',
#  'Coolpix P90',
#  'DMC-TZ6EG-K',
#  '0001820826206',
#  '1030SW',
#  'SJ4KYDYEL',
#  'Dimage A1',
#  'A95',
#  'K-5',
#  'V1073',
#  'X-T1',
#  'Om-d e-m1 with m.Zuiko Digital 12 - 40 mm f2.8 - pro',
#  'PC1102',
#  'a3000',
#  'Canon EOS\nA viewfinder is the small square on the back of a camera that you look through to compose the scene. Some cameras have small screens on the back that act as viewfinders. Other cameras have small glass areas through which you can look out of the front of the camera.',
#  'D5300',
#  'DMC-GM1',
#  'EOS-1',
#  '10MP Digital Camera',
#  'S30HDZ',
#  '0002724284359',
#  'V205041BU000',
#  '1525',
#  'V25',
#  'ILLUM',
#  'WB800F',
#  'L4',
#  '16225391',
#  '0001820825488',
#  'IC-LBMW60-ASF',
#  'NEX-5N',
#  'IPC-HFW3200CP',
#  'SD6C36E-H',
#  'VT-9813B',
#  'Hvr-Hd1000p',
#  'IC-LDMW30-DSR',
#  'DH-IPC-HFW5200CP DH-IPC-HFW5200CN',
#  'DMCFX37A',
#  'Underwater Digital Camera',
#  'MV',
#  'HD Ghost',
#  'IC-LBMW30-ESR IC-LBMW30-ESS IC-LBMW30-ESA IC-LBMW30-ESQ IC-LBMW30-ESK IC-LBMW30-ESF',
#  'Mavica',
#  'K-S1',
#  'DMC-LZ30',
#  'ZAF1031-S-LA',
#  'sp500',
#  'VPC-S1285W',
#  'kp-65wv600',
#  'S9600',
#  '800',
#  'IPC-IP2P02',
#  '64gb HDR-Pj820e/b with Projector, Electronic View Finder & wi-Fi/NFC Full HD',
#  'Optio M40',
#  'W90',
#  '1523372',
#  'DF-7548RN DF-7554RN DF-7549ZTR DF-7548WDR',
#  'VT-9413HB',
#  'DMC-GM1K',
#  '*istDL',
#  '0007410100801',
#  '25476',
#  'DMC-FZ40/DMC-FZ45',
#  'RX100II',
#  'LC-90LE657U',
#  'Digital Concepts',
#  'VPC-T850',
#  'DS6688',
#  'DSC-W510',
#  'PRO815',
#  '0002707514755',
#  'S3000',
#  '8700',
#  'HS-7362',
#  'Kodak ZM1 Mini Digital Camcorder',
#  'TOP-428LIR-SY1010P',
#  'S8400W',
#  'A3000',
#  'AV100',
#  'SAV-CD296A',
#  'DH-IPC-HDB3200CN',
#  'ST72',
#  'DMC-LZ10',
#  '0005033217358',
#  'CD33',
#  'IPH17DB2-IR2',
#  'A330',
#  'LED50B45RQ',
#  '506V',
#  'A570 IS',
#  'E-500',
#  'C-450 Zoom',
#  '3593278',
#  'S6100',
#  'A500',
#  '0004470101540',
#  'S1500',
#  'JLB-W5000',
#  'ViviCam 7020',
#  '14664',
#  'DH-IPC-HFW2100N',
#  'Z1015 IS',
#  'DMC-ZS8',
#  'DSC-W580',
#  'DSC-P200',
#  'VT-8118Z',
#  'M320',
#  'M341',
#  'Cybershot Dsc-Hx7v',
#  'Sony SLT-A37',
#  'SD400',
#  'J250',
#  'SX500IS',
#  'DXG-518',
#  'DSC-WX1',
#  'Xg',
#  'AH17WF-IR2',
#  'Az361',
#  'FinePix J10',
#  '0001820826286',
#  'Galaxy Camera 2',
#  'BE-SDO70Z',
#  'DH-IPC-HFW4100SP',
#  'Sony SLT-A65',
#  'HD-SD6582A-HS',
#  'EX-Z85',
#  'L210',
#  'T410',
#  'SD6C23E-H',
#  'DH-SD6AW230-HN',
#  'L830',
#  'Ilce-3500jy with Sel1850 & Sel55210 Lens',
#  'Cantilever',
#  '645DF',
#  'IC-LBMW40-DSR',
#  '24 Class Razor LED',
#  'HV-72QIC',
#  'DF-3003RN DF-3003R',
#  'Mark lll',
#  'DMC-ZS19',
#  'Kiss Digital X',
#  'Coolpix S8100',
#  '820',
#  'S9050',
#  'x500',
#  'GXR P10',
#  'X2',
#  '6150s',
#  'T24C550ND',
#  'Hx-dc2',
#  'FZ70K',
#  'S1',
#  'DSC-V3',
#  'EOS Rebel XT 350D',
#  'PST-HT101D',
#  'UN50EH5000',
#  'SD22W',
#  'S4100',
#  'DH-IPC-HD2100P DH-IPC-HD2100N',
#  'E-PL2',
#  'NX1100',
#  'C1440 W',
#  'S2000HD',
#  'Nex-7',
#  'C-60 Zoom',
#  'Exilim',
#  '13302',
#  'DSC-S75',
#  'ViviCam 5024',
#  'Coolpix s60',
#  '13306',
#  'FE-130',
#  '0002724286222',
#  'HDV-TIP130M40C10-P3.7',
#  'SX50',
#  'YC-759AHZ31',
#  '26439',
#  'GS-HDR140',
#  'Finepix F500 EXR',
#  '1Ds',
#  'MDC 5000',
#  'IC-LD20-ASR',
#  'DSC-HX50V',
#  'TX55',
#  'Rebel XT',
#  'SX700HS',
#  'Sdr-s71',
#  '226500',
#  'Nikon D5200',
#  'DSC-W650',
#  'EOS M2',
#  'Clip',
#  'J1458W',
#  'Panasonic Lumix',
#  'D400',
#  '1DX',
#  'DSC-P93',
#  'VX137-BLK',
#  'SD950 IS',
#  'Harinezumi guru',
#  'ST-S360',
#  'BV40W-S88K BV40W-S82K BV40W-S72K BV40W-S70K BV40W-S65K BV40W-C80K',
#  'BV40W-S65K',
#  '300D',
#  'DX4530',
#  'S3',
#  'SY2568S',
#  '0001820826278',
#  'X2600-EP/B',
#  'DSC-H400',
#  'DC-M10B2-VP',
#  'P1',
#  'FE-350 Wide',
#  ...}

# %%
'IC-LDMW30-ASS' in models
# Out:
# True
